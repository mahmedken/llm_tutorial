# %% [markdown]
# # Finetuning llama 3.2 3b for text classification (imdb reviews)
#
# In this tutorial, we will finetune a llama 3.2 3b model for text classification on the imdb movie reviews dataset. This is a binary sentiment classification task. The reveiws are classified as positive or negative.
#
# Llama is an open-source, autoregressive, large language model and can be finetuned for various tasks including text classification.
#
# We will use parameter efficient finetuning (PEFT) to finetune the model using low-rank adaptation (LoRA). This technique allows us to finetune the model with a small number of parameters instead of the full model, making it more efficient and cost-effective.
#
# After finetuning, we can store only the LoRA parameters, which are much smaller than the full model parameters.
#
# This tutorial is based on the following online [tutorial](https://www.datacamp.com/tutorial/fine-tuning-llama-3-1)

# %% [markdown]
# first step is to acquire the licence to use the model weights. you can do this on huggingface, meta or kaggle. it requires minimal information about the user. once you have the licence, you can download the model weights from the model hub. in this tutorial, we will use the llama 3.2 3b model from huggingface.

# %% [markdown]
# the packages we will use for this tutorial are:
#
# - transformers
# - accelerate
# - bitsandbytes
# - peft
# - trl
#
# make sure to install these packages before running the code.
#
# ```bash
# pip install transformers accelerate bitsandbytes peft trl
# ```
#
# we will use the `transformers` library to load the llama 3.2 3b model and finetune it for text classification.
#
# the `accelerate` library will help us manage the training process and use the GPU for faster training.
#
# the `bitsandbytes` library will help us load the model with 8-bit quantization, which is more efficient than full 32-bit precision.

# %%
import os
from dotenv import load_dotenv

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

load_dotenv()

HF_token = os.getenv("HF_token")
CACHE_DIR = os.getenv("CACHE_DIR")
OUTPUT_DIR = "./llama_finetuned"
WANDB_PROJECT = "llama-imdb-finetuning"

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# %%
# libs imports
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import bitsandbytes as bnb
import torch
import torch.nn as nn
import transformers
from datasets import Dataset
from peft import LoraConfig, PeftConfig
from trl import SFTTrainer, SFTConfig
from trl import setup_chat_format
from transformers import (AutoModelForCausalLM, 
                          AutoTokenizer, 
                          BitsAndBytesConfig, 
                          TrainingArguments, 
                          pipeline, 
                          logging)
from sklearn.metrics import (accuracy_score, 
                             classification_report, 
                             confusion_matrix)
from sklearn.model_selection import train_test_split
from datasets import Dataset
from accelerate import Accelerator

# %%
# important step when using accelerator to set the device index so that the model and the peft adapter are loaded on the same device


device_index = Accelerator().process_index

print(f"Using device index: {device_index}")

device_map = {"": device_index}
# Out:
# Using device index: 0

# %% [markdown]
# in this step we will load and process the dataset. to simplify things, we will use the same imdb dataset that we used with bert. recall this is a dataset of 50,000 movie reviews from the internet movie database. the reviews are labeled as positive or negative.
#
# after loading the dataset, we need to append our prompt to the begining of each review since we are finetuning a chat model.
#
# the training prompt structure is as follows:
#
# ```
# classify the sentiment of the following movie review as positive or negative. Respond with 'positive' or 'negative' and nothing else.
# review: {text}
# sentiment_label: {label}
# ```
#
# the test prompt structure is as follows:
#
# ```
# classify the sentiment of the following movie review as positive or negative. Respond with 'positive' or 'negative' and nothing else.
# review: {text}
# sentiment_label:
# ```
#
# in this way we are instructing the model to generate the sentiment label (next token) for the review.

# %%
from bert_model import load_imdb_data

def generate_prompt(item):
    label = 'positive' if item['label'] == 1 else 'negative'
    prompt = f"""classify the sentiment of the following movie review as positive or negative. Respond with 'positive' or 'negative' and nothing else.

    review: {item['review']}
    sentiment_label: {label}
    """.strip()
    return {"text": prompt}

def generate_test_prompt(item):
    prompt = f"""classify the sentiment of the following movie review as positive or negative. Respond with 'positive' or 'negative' and nothing else.

    review: {item['review']}
    sentiment_label:
    """.strip()
    return {"text": prompt}

train_texts, train_labels, val_texts, val_labels, test_texts, test_labels = load_imdb_data(dataset_fraction=0.1)

train_dict = {
    'review': train_texts,
    'label': train_labels,
}

val_dict = {
    'review': val_texts,
    'label': val_labels,
}

test_dict = {
    'review': test_texts,
    'label': test_labels,
}

train_dataset = Dataset.from_dict(train_dict)
val_dataset = Dataset.from_dict(val_dict)
test_dataset = Dataset.from_dict(test_dict)

train_dataset = train_dataset.map(generate_prompt)
val_dataset = val_dataset.map(generate_prompt)
test_dataset = test_dataset.map(generate_test_prompt)

# print a sample of the dataset
print(train_dataset[0])
# Out:
# loading imdb dataset...
# using 10.0% of dataset
# train label distribution: Counter({1: 1258, 0: 1242})
# test label distribution: Counter({1: 1258, 0: 1242})
# train samples: 2500
# validation samples: 500
# test samples: 2000
# example review: An unusually straight-faced actioner played by a cast and filmed by a director who obviously took the material seriously. Imperfect, as is to be expected from a film clearly shot on a tight budget, bu...
# example label: 1 (positive)
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# {'review': 'An unusually straight-faced actioner played by a cast and filmed by a director who obviously took the material seriously. Imperfect, as is to be expected from a film clearly shot on a tight budget, but the drama is involving-- it\'s one of those films that when it gets repeated ad nauseum on Cinemax 2 or More Max or whatever they call it, you end up watching 40 minute blocks when you\'re supposed to be going to work. Along W/ "Deathstalker 2", "Chopping Mall", and "The Assault", a reminder that Wynorski is a much more talented director than many of his fellow low-budget brethern, who has a real ability to pace a genre film, when he actually\'s interested in the material (i.e., don\'t bother watching any of his Shannon Tweed flicks with a 3 or a 4 after the title!) Actors who\'ve had too little to do recently (Mancuso, Ford, even Gary Sandy for chrissakes) really put their all into some of their best roles in years -- as for Grieco, he has the right look, although his acting is a bit one-note -- it\'s clear his character is supposed to be self-destructing throughout the film, but Grieco doesn\'t quite convey it. I checked IMDB and I see the writer also wrote "Sorority House Massacre 2" & "Dinosaur Island" for the director -- both minor classics in their own rights, but obviously "silly" Roger Cormon-like Cinema -- this one\'s more like some of the better Jonathan Demme and Jonathan Kaplan B-pictures of the 70\'s -- giving you the exploitation element but offering involving drama at the same time -- a real step forward. Not "Citizen Kane," and the comic final moments are a bit disruptive, but a well-written, character-driven above-average straight-to-video actioner. Small achievements like this should not be overlooked when they come along, which is rare enough (as I was reminded as I tried to sit through an Albert Pyun monstrosity called "Heatseeker" the other night -- this low-budget stuff isn\'t as easy as it looks -- but that\'s another story!)', 'label': 1, 'text': 'classify the sentiment of the following movie review as positive or negative. Respond with \'positive\' or \'negative\' and nothing else.\n\n    review: An unusually straight-faced actioner played by a cast and filmed by a director who obviously took the material seriously. Imperfect, as is to be expected from a film clearly shot on a tight budget, but the drama is involving-- it\'s one of those films that when it gets repeated ad nauseum on Cinemax 2 or More Max or whatever they call it, you end up watching 40 minute blocks when you\'re supposed to be going to work. Along W/ "Deathstalker 2", "Chopping Mall", and "The Assault", a reminder that Wynorski is a much more talented director than many of his fellow low-budget brethern, who has a real ability to pace a genre film, when he actually\'s interested in the material (i.e., don\'t bother watching any of his Shannon Tweed flicks with a 3 or a 4 after the title!) Actors who\'ve had too little to do recently (Mancuso, Ford, even Gary Sandy for chrissakes) really put their all into some of their best roles in years -- as for Grieco, he has the right look, although his acting is a bit one-note -- it\'s clear his character is supposed to be self-destructing throughout the film, but Grieco doesn\'t quite convey it. I checked IMDB and I see the writer also wrote "Sorority House Massacre 2" & "Dinosaur Island" for the director -- both minor classics in their own rights, but obviously "silly" Roger Cormon-like Cinema -- this one\'s more like some of the better Jonathan Demme and Jonathan Kaplan B-pictures of the 70\'s -- giving you the exploitation element but offering involving drama at the same time -- a real step forward. Not "Citizen Kane," and the comic final moments are a bit disruptive, but a well-written, character-driven above-average straight-to-video actioner. Small achievements like this should not be overlooked when they come along, which is rare enough (as I was reminded as I tried to sit thro ...

# %% [markdown]
# now we will load the model and tokenizer. we will use the llama 3.2 3b model from the huggingface model hub. the model card can be found [here](https://huggingface.co/meta-llama/Llama-3.2-1B-Instruct).

# %%
base_model_name = "meta-llama/Llama-3.2-3B-Instruct"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16",
)

current_device = 2  # load model on gpu 3 - very important for quantized training
model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    device_map=device_map,  # use current device instead of auto
    torch_dtype="float16",
    quantization_config=bnb_config,
    cache_dir=CACHE_DIR,
)

model.config.use_cache = False
model.config.pretraining_tp = 1

tokenizer = AutoTokenizer.from_pretrained(base_model_name)

tokenizer.pad_token_id = tokenizer.eos_token_id
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# before finetuning, let's evaluate the model on the test set to measure its baseline performance.

# %%
def predict(test_dataset, model, tokenizer):
    y_pred = []
    categories = ["positive", "negative"]
    
    for i in tqdm(range(len(test_dataset))):
        prompt = test_dataset[i]["text"]
        pipe = pipeline(task="text-generation", 
                        model=model, 
                        tokenizer=tokenizer, 
                        max_new_tokens=2, 
                        temperature=0.1)
        
        result = pipe(prompt)
        answer = result[0]['generated_text'].split("sentiment_label:")[-1].strip()
        
        # determine the predicted category
        for category in categories:
            if category.lower() in answer.lower():
                y_pred.append(category)
                break
        else:
            y_pred.append("none")
    
    return y_pred



y_pred = predict(test_dataset, model, tokenizer)

print(y_pred)

# %% [markdown]
# next we evaluate the baselinemodel's performance on the test set.

# %%
def evaluate(y_true, y_pred):
    labels = ["positive", "negative"]
    mapping = {label: idx for idx, label in enumerate(labels)}
    
    def map_func(x):
        return mapping.get(x, -1)  # Map to -1 if not found, but should not occur with correct data
    
    y_true_mapped = np.vectorize(map_func)(y_true)
    y_pred_mapped = np.vectorize(map_func)(y_pred)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_true=y_true_mapped, y_pred=y_pred_mapped)
    print(f'Accuracy: {accuracy:.3f}')
    
    # Generate accuracy report
    unique_labels = set(y_true_mapped)  # Get unique labels
    
    for label in unique_labels:
        label_indices = [i for i in range(len(y_true_mapped)) if y_true_mapped[i] == label]
        label_y_true = [y_true_mapped[i] for i in label_indices]
        label_y_pred = [y_pred_mapped[i] for i in label_indices]
        label_accuracy = accuracy_score(label_y_true, label_y_pred)
        print(f'Accuracy for label {labels[label]}: {label_accuracy:.3f}')
        
    # Generate classification report
    class_report = classification_report(y_true=y_true_mapped, y_pred=y_pred_mapped, target_names=labels, labels=list(range(len(labels))))
    print('\nClassification Report:')
    print(class_report)
    
    # Generate confusion matrix
    conf_matrix = confusion_matrix(y_true=y_true_mapped, y_pred=y_pred_mapped, labels=list(range(len(labels))))
    print('\nConfusion Matrix:')
    print(conf_matrix)

y_true = test_dataset["label"]
y_true = ["positive" if label == 1 else "negative" for label in y_true]
evaluate(y_true, y_pred)
# Out:
# Accuracy: 0.930
# Accuracy for label positive: 0.957
# Accuracy for label negative: 0.903
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     positive       0.91      0.96      0.93      1006
#     negative       0.96      0.90      0.93       994
#
#    micro avg       0.93      0.93      0.93      2000
#    macro avg       0.93      0.93      0.93      2000
# weighted avg       0.93      0.93      0.93      2000
#
#
# Confusion Matrix:
# [[963  42]
#  [ 95 898]]

# %% [markdown]
# as you can see, the model is already at a very good accuracy. that's because the dataset is super easy. let's see if we can push it a bit more by finetuning.

# %% [markdown]
# we will start building the model according to the following steps:
#
# 1. we extract all the linear modules from the models using the bitsandbytes library.
# 2. then we configure LoRA to target these linear modules.
# 3. we create a trainer object that will handle (and abstract) the training loop. using the trl library.
# 4. we train and evaluate the model.

# %%
import bitsandbytes as bnb

def find_all_linear_names(model):
    cls = bnb.nn.Linear4bit
    lora_module_names = set()
    for name, module in model.named_modules():
        if isinstance(module, cls):
            names = name.split('.')
            lora_module_names.add(names[0] if len(names) == 1 else names[-1])
    if 'lm_head' in lora_module_names:  # needed for 16 bit
        lora_module_names.remove('lm_head')
    return list(lora_module_names)
modules = find_all_linear_names(model)
modules
# Out:
# ['up_proj', 'down_proj', 'o_proj', 'v_proj', 'k_proj', 'q_proj', 'gate_proj']

# %% [markdown]
# before we start training we want to keep track of our training process and evals. in this tutorial, we will use weights and biases (wandb) which is a tool with a nice UI and a lot of features.
#
# ```bash
# pip install wandb
# ```
#
# ```

# %%
import wandb

wandb.login()

wandb.init(project=WANDB_PROJECT)


run = wandb.init(project=WANDB_PROJECT, job_type="training")
# Out:
# wandb: Currently logged in as: kennygu (kennygu-georgetown-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/cs-data-01/ma2323/llm_tutorial/wandb/run-20250702_035319-dzelgopb</code>
# Syncing run <strong><a href='https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning/runs/dzelgopb' target="_blank">dainty-star-5</a></strong> to <a href='https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning' target="_blank">https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning</a>
#  View run at <a href='https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning/runs/dzelgopb' target="_blank">https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning/runs/dzelgopb</a>

# %%
# main training loop

output_dir= OUTPUT_DIR

peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=modules,
)


sft_config = SFTConfig(
    output_dir=output_dir,                    # directory to save and repository id
    num_train_epochs=1,                       # number of training epochs
    per_device_train_batch_size=1,            # batch size per device during training
    gradient_accumulation_steps=8,            # number of steps before performing a backward/update pass
    gradient_checkpointing=True,              # use gradient checkpointing to save memory
    optim="paged_adamw_32bit",
    logging_steps=1,                         
    learning_rate=2e-4,                       # learning rate, based on QLoRA paper
    weight_decay=0.001,
    fp16=True,
    bf16=False,
    max_grad_norm=0.3,                        # max gradient norm based on QLoRA paper
    max_steps=-1,
    warmup_ratio=0.03,                        # warmup ratio based on QLoRA paper
    group_by_length=False,
    lr_scheduler_type="cosine",               # use cosine learning rate scheduler
    report_to="wandb",                  # report metrics to w&b
    do_eval=True,
    eval_strategy="steps",              # save checkpoint every epoch
    eval_steps = 0.05,
    dataset_text_field="text",
    max_seq_length=512,
    packing=False,
    dataset_kwargs={"add_special_tokens": False, "append_concat_token": False},
    run_name="llama-imdb-finetuning_e1",
)


trainer = SFTTrainer(
    model=model,
    args=sft_config,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    peft_config=peft_config,
    processing_class=tokenizer
)

# name wb run
run.name = "llama-imdb-finetuning_e1"
# Out:
# average_tokens_across_devices is set to True but it is invalid when world size is1. Turn it to False automatically.
# Adding EOS to train dataset:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/500 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/500 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/500 [00:00<?, ? examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.

# %%
# now it's time to start the training loop
trainer.train()
# Out:
#     <div>
#
#       <progress value='313' max='313' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [313/313 17:01, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>16</td>
#       <td>2.819100</td>
#       <td>2.717163</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>2.622300</td>
#       <td>2.678006</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>2.651600</td>
#       <td>2.632457</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>2.880100</td>
#       <td>2.625839</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.735400</td>
#       <td>2.619114</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>2.702100</td>
#       <td>2.615744</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>2.534000</td>
#       <td>2.613143</td>
#     </tr>
#     <tr>
#       <td>128</td>
#       <td>2.451700</td>
#       <td>2.610193</td>
#     </tr>
#     <tr>
#       <td>144</td>
#       <td>2.521100</td>
#       <td>2.608157</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>2.617000</td>
#       <td>2.606247</td>
#     </tr>
#     <tr>
#       <td>176</td>
#       <td>2.667500</td>
#       <td>2.604191</td>
#     </tr>
#     <tr>
#       <td>192</td>
#       <td>2.534000</td>
#       <td>2.602871</td>
#     </tr>
#     <tr>
#       <td>208</td>
#       <td>2.560300</td>
#       <td>2.601293</td>
#     </tr>
#     <tr>
#       <td>224</td>
#       <td>2.568100</td>
#       <td>2.599940</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>2.250400</td>
#       <td>2.599132</td>
#     </tr>
#     <tr>
#       <td>256</td>
#       <td>2.624200</td>
#       <td>2.598407</td>
#     </tr>
#     <tr>
#       <td>272</td>
#       <td>2.599800</td>
#       <td>2.597917</td>
#     </tr>
#     <tr>
#       <td>288</td>
#       <td>2.605700</td>
#       <td>2.597720</td>
#     </tr>
#     <tr>
#       <td>304</td>
#       <td>2.609700</td>
#       <td>2.597664</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=313, training_loss=2.6217566930447904, metrics={'train_runtime': 1023.7772, 'train_samples_per_second': 2.442, 'train_steps_per_second': 0.306, 'total_flos': 1.3084378739656704e+16, 'train_loss': 2.6217566930447904})

# %%
# finish wandb run and set the model to use cache for inference
wandb.finish()
model.config.use_cache = True
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▆▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/mean_token_accuracy</td><td>▁▃▆▆▇▇▇▇▇▇▇████████</td></tr><tr><td>eval/num_tokens</td><td>▁▁▂▂▃▃▃▄▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>eval/runtime</td><td>▁▆██▇▇▆▆███▆▇▇▇▆▇▇▆</td></tr><tr><td>eval/samples_per_second</td><td>█▃▁▁▂▂▃▂▁▂▁▃▂▂▂▃▂▂▃</td></tr><tr><td>eval/steps_per_second</td><td>█▃▁▁▂▂▂▂▁▁▁▂▂▂▂▂▂▂▃</td></tr><tr><td>train/epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▇▇▇▇█</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train/grad_norm</td><td>▅▃▃▃█▆▅▆▅█▃▄▆▄▃▄▅▃▄▆▃▃▄▅▅▃▃▅▄▄▅▅▄▄▅▂▅▃▄▁</td></tr><tr><td>train/learning_rate</td><td>████████▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▆▃▆▃▄▄▅▄▅▄▃▄▄▅▄▄▄▅▃▅▂▃▄▃▄▄▃▂▄▃▃▄▄▄▃▄▁▄▃</td></tr><tr><td>train/mean_token_accuracy</td><td>▁▂▃▅▆▁▅▄▄▇▇▆▆▅▅▅▆▆▆▆▇▅▄▄▆▆▆▃▇▄▄▅▇▄█▅▅▂▅▄</td></tr><tr><td>train/num_tokens</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>2.59766</td></tr><tr><td>eval/mean_token_accuracy</td><td>0.48478</td></tr><tr><td>eval/num_tokens</td><td>727007</td></tr><tr><td>eval/runtime</td><td>26.9277</td></tr><tr><td>eval/samples_per_second</td><td>18.568</td></tr><tr><td>eval/steps_per_second</td><td>2.34</td></tr><tr><td>total_flos</td><td>1.3084378739656704e+16</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>313</td></tr><tr><td>train/grad_norm</td><td>0.20922</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>2.682</td></tr><tr><td>train/mean_token_accuracy</td><td>0.49758</td></tr><tr><td>train/num_tokens</td><td>747849</td></tr><tr><td>train_loss</td><td>2.62176</td></tr><tr><td>train_runtime</td><td>1023.7772</td></tr><tr><td>train_samples_per_second</td><td>2.442</td></tr><tr><td>train_steps_per_second</td><td>0.306</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">llama-imdb-finetuning_e1</strong> at: <a href='https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning/runs/dzelgopb' target="_blank">https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning/runs/dzelgopb</a><br> View project at: <a href='https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning' target="_blank">https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250702_035319-dzelgopb/logs</code>

# %%
# save the model and tokenizer for inference (later)
model.save_pretrained(OUTPUT_DIR)
tokenizer.save_pretrained(OUTPUT_DIR)
# Out:
# ('./llama_finetuned/tokenizer_config.json',
#  './llama_finetuned/special_tokens_map.json',
#  './llama_finetuned/chat_template.jinja',
#  './llama_finetuned/tokenizer.json')

# %% [markdown]
# let's evaluate our finetuned model on the test set.

# %%
# evaluate the finetuned model on the test set (similar to what we did in the baseline model)

y_true = test_dataset["label"]
y_true = ["positive" if label == 1 else "negative" for label in y_true]
y_pred = predict(test_dataset, model, tokenizer)
evaluate(y_true, y_pred)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]Device set to use cuda:0
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# /cs-data-01/ma2323/condatorch/lib/python3.13/site-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#   0%|          | 1/2000 [00:00<09:17,  3.59it/s]Device set to use cuda:0
#   0%|          | 2/2000 [00:00<06:00,  5.55it/s]Device set to use cuda:0
#   0%|          | 3/2000 [00:00<06:49,  4.88it/s]Device set to use cuda:0
#   0%|          | 4/2000 [00:00<06:28,  5.14it/s]Device set to use cuda:0
#   0%|          | 5/2000 [00:00<05:43,  5.81it/s]Device set to use cuda:0
#   0%|          | 6/2000 [00:01<05:09,  6.44it/s]Device set to use cuda:0
#   0%|          | 7/2000 [00:01<05:04,  6.55it/s]Device set to use cuda:0
# Device set to use cuda:0
#   0%|          | 9/2000 [00:01<05:38,  5.88it/s]Device set to use cuda:0
#   0%|          | 10/2000 [00:01<05:07,  6.47it/s]Device set to use cuda:0
#   1%|          | 11/2000 [00:01<04:43,  7.02it/s]Device set to use cuda:0
#   1%|          | 12/2000 [00:01<04:38,  7.13it/s]Device set to use cuda:0
#   1%|          | 13/2000 [00:02<04:19,  7.66it/s]Device set to use cuda:0
# Device set to use cuda:0
#   1%|          | 15/2000 [00:02<04:10,  7.92it/s]Device set to use cuda:0
#   1%|          | 16/2000 [00:02<04:06,  8.03it/s]Device set to use cuda:0
#   1%|          | 17/2000 [00:02<04:17,  7.70it/s]Device set to use cuda:0
#   1%|          | 18/2000 [00:02<04:11,  7.88it/s]Device set to use cuda:0
#   1%|          | 19/2000 [00:02<04:01,  8.22it/s]Device set to use cuda:0
#   1%|          | 20/2000 [00:02<03:53,  8.48it/s]Device set to use cuda:0
#   1%|          | 21/2000 [00:03<03:53,  8.49it/s]Device set to use cuda:0
#   1%|          | 22/2000 [00:03<03:48,  8.67it/s]Device set to use cuda:0
#   1%|          | 23/2000 [00:03<03:50,  8.58it/s]Device set to use cuda:0
# Device set to use cuda:0
#   1%|▏         | 25/2000 [00:03<03:40,  8.97it/s]Device set to use cuda:0
#   1%|▏         | 26/2000 [00:03<05:03,  6.49it/s]Device set to use cuda:0
#   1%|▏         | 27/2000 [00:03<05:17,  6.22it/s]Device set to use cuda:0
#   1%|▏         | 28/2000 [00:04<06:20,  5.18it/s]Device set to use cuda:0
#   1%|▏         | 29/2000 [00:04<05:34,  5.89it/s]Device set to use cuda:0
#   2%|▏         | 30/2000 [00:04<05:01,  6.54it/s]Device set to use cuda:0
#   2%|▏         | 31/2000 [00:04<04:41,  6.99it/s]Device set to use cuda:0
#   2%|▏         | 32/2000 [00:04<04:26,  7.38it/s]Device set to use cuda:0
#   2%|▏         | 33/2000 [00:04<04:17,  7.64it/s]Device set to use cuda:0
#   2%|▏         | 34/2000 [00:05<05:53,  5.56it/s]Device set to use cuda:0
#   2%|▏         | 35/2000 [00:05<05:14,  6.25it/s]Device set to use cuda:0
#   2%|▏         | 36/2000 [00:05<04:57,  6.61it/s]Device set to use cuda:0
#   2%|▏         | 37/2000 [00:05<04:48,  6.80it/s]Device set to use cuda:0
#   2%|▏         | 38/2000 [00:05<04:32,  7.19it/s]Device set to use cuda:0
#   2%|▏         | 39/2000 [00:05<04:16,  7.66it/s]Device set to use cuda:0
#   2%|▏         | 40/2000 [00:05<04:08,  7.88it/s]Device set to use cuda:0
#   2%|▏         | 41/2000 [00:05<04:03,  8.05it/s]Device set to use cuda:0
#   2%|▏         | 42/2000 [00:06<03:55,  8.31it/s]Device set to use cuda:0
#   2%|▏         | 43/2000 [00:06<03:55,  8.32it/s]Device set to use cuda:0
#   2%|▏         | 44/2000 [00:06<04:11,  7.79it/s]Device set to use cuda:0
#   2%|▏         | 45/2000 [00:06<04:06,  7.93it/s]Device set to use cuda:0
#   2%|▏         | 46/2000 [00:06<04:12,  7.75it/s]Device set to use cuda:0
#   2%|▏         | 47/2000 [00:06<04:13,  7.69it/s]Device set to use cuda:0
#   2%|▏         | 48/2000 [00:06<04:26,  7.34it/s]Device set to use cuda:0
#   2%|▏         | 49/2000 [00:06<04:08,  7.84it/s]Device set to use cuda:0
#   2%|▎         | 50/2000 [00:07<04:03,  8.00it/s]Device set to use cuda:0
#   3%|▎         | 51/2000 [00:07<04:10,  7.78it/s]Device set to use cuda:0
#   3%|▎         | 52/2000 [00:07<04:04,  7.97it/s]Device set to use cuda:0
#   3%|▎         | 53/2000 [00:07<03:56,  8.24it/s]Device set to use cuda:0
#   3%|▎         | 54/2000 [00:07<03:47,  8.56it/s]Device set to use cuda:0
#   3%|▎         | 55/2000 [00:07<03:55,  8.25it/s]Device set to use cuda:0
#   3%|▎         | 56/2000 [00:07<03:50,  8.43it/s]Device set to use cuda:0
#   3%|▎         | 57/2000 [00:07<04:31,  7.15it/s]Device set to use cuda:0
#   3%|▎         | 58/2000 [00:08<04:14,  7.63it/s]Device set to use cuda:0
#   3%|▎         | 59/2000 [00:08<04:25,  7.32it/s]Device set to use cuda:0
#   3%|▎         | 60/2000 [00:08<04:26,  7.29it/s]Device set to use cuda:0
#   3%|▎         | 61/2000 [00:08<04:14,  7.61it/s]Device set to use cuda:0
#   3%|▎         | 62/2000 [00:08<04:01,  8.03it/s]Device set to use cuda:0
#   3%|▎         | 63/2000 [00:08<03:57,  8.15it/s]Device set to use cuda:0
#   3%|▎         | 64/2000 [00:08<05:03,  6.39it/s]Device set to use cuda:0
# Device set to use cuda:0
#   3%|▎         | 66/2000 [00:09<04:38,  6.96it/s]Device set to use cuda:0
#   3%|▎         | 67/2000 [00:09<04:42,  6.84it/s]Device set to use cuda:0
#   3%|▎         | 68/2000 [00:09<04:49,  6.66it/s]Device set to use cuda:0
#   3%|▎         | 69/2000 [00:09<04:32,  7.08it/s]Device set to use cuda:0
#   4%|▎         | 70/2000 [00:09<04:15,  7.56it/s]Device set to use cuda:0
#   4%|▎         | 71/2000 [00:09<04:00,  8.01it/s]Device set to use cuda:0
#   4%|▎         | 72/2000 [00:09<03:58,  8.07it/s]Device set to use cuda:0
#   4%|▎         | 73/2000 [00:10<03:55,  8.19it/s]Device set to use cuda:0
#   4%|▎         | 74/2000 [00:10<05:08,  6.25it/s]Device set to use cuda:0
#   4%|▍         | 75/2000 [00:10<05:03,  6.35it/s]Device set to use cuda:0
# Device set to use cuda:0
#   4%|▍         | 77/2000 [00:10<04:18,  7.44it/s]Device set to use cuda:0
#   4%|▍         | 78/2000 [00:10<04:58,  6.43it/s]Device set to use cuda:0
#   4%|▍         | 79/2000 [00:11<05:11,  6.17it/s]Device set to use cuda:0
#   4%|▍         | 80/2000 [00:11<05:18,  6.03it/s]Device set to use cuda:0
#   4%|▍         | 81/2000 [00:11<04:47,  6.67it/s]Device set to use cuda:0
#   4%|▍         | 82/2000 [00:11<04:26,  7.21it/s]Device set to use cuda:0
# Device set to use cuda:0
#   4%|▍         | 84/2000 [00:11<03:55,  8.15it/s]Device set to use cuda:0
#   4%|▍         | 85/2000 [00:11<04:06,  7.76it/s]Device set to use cuda:0
#   4%|▍         | 86/2000 [00:11<04:02,  7.89it/s]Device set to use cuda:0
#   4%|▍         | 87/2000 [00:12<04:42,  6.76it/s]Device set to use cuda:0
#   4%|▍         | 88/2000 [00:12<04:45,  6.70it/s]Device set to use cuda:0
# Device set to use cuda:0
#   4%|▍         | 90/2000 [00:12<04:16,  7.45it/s]Device set to use cuda:0
#   5%|▍         | 91/2000 [00:12<04:06,  7.76it/s]Device set to use cuda:0
#   5%|▍         | 92/2000 [00:13<05:50,  5.45it/s]Device set to use cuda:0
#   5%|▍         | 93/2000 [00:13<05:47,  5.48it/s]Device set to use cuda:0
# Device set to use cuda:0
#   5%|▍         | 95/2000 [00:13<04:44,  6.69it/s]Device set to use cuda:0
#   5%|▍         | 96/2000 [00:13<04:30,  7.03it/s]Device set to use cuda:0
#   5%|▍         | 97/2000 [00:13<04:18,  7.35it/s]Device set to use cuda:0
#   5%|▍         | 98/2000 [00:13<04:04,  7.78it/s]Device set to use cuda:0
# Device set to use cuda:0
#   5%|▌         | 100/2000 [00:13<03:48,  8.33it/s]Device set to use cuda:0
#   5%|▌         | 101/2000 [00:14<03:54,  8.10it/s]Device set to use cuda:0
# Device set to use cuda:0
#   5%|▌         | 103/2000 [00:14<03:55,  8.07it/s]Device set to use cuda:0
#   5%|▌         | 104/2000 [00:14<04:05,  7.74it/s]Device set to use cuda:0
#   5%|▌         | 105/2000 [00:14<04:00,  7.89it/s]Device set to use cuda:0
#   5%|▌         | 106/2000 [00:14<04:18,  7.31it/s]Device set to use cuda:0
#   5%|▌         | 107/2000 [00:14<04:05,  7.70it/s]Device set to use cuda:0
#   5%|▌         | 108/2000 [00:15<03:59,  7.89it/s]Device set to use cuda:0
#   5%|▌         | 109/2000 [00:15<04:12,  7.49it/s]Device set to use cuda:0
#   6%|▌         | 110/2000 [00:15<04:13,  7.46it/s]Device set to use cuda:0
#   6%|▌         | 111/2000 [00:15<04:04,  7.72it/s]Device set to use cuda:0
#   6%|▌         | 112/2000 [00:15<03:57,  7.94it/s]Device set to use cuda:0
#   6%|▌         | 113/2000 [00:15<03:49,  8.24it/s]Device set to use cuda:0
#   6%|▌         | 114/2000 [00:15<03:40,  8.54it/s]Device set to use cuda:0
#   6%|▌         | 115/2000 [00:15<03:42,  8.46it/s]Device set to use cuda:0
#   6%|▌         | 116/2000 [00:16<03:52,  8.11it/s]Device set to use cuda:0
#   6%|▌         | 117/2000 [00:16<03:49,  8.22it/s]Device set to use cuda:0
#   6%|▌         | 118/2000 [00:16<04:43,  6.63it/s]Device set to use cuda:0
#   6%|▌         | 119/2000 [00:16<04:25,  7.07it/s]Device set to use cuda:0
#   6%|▌         | 120/2000 [00:16<04:21,  7.19it/s]Device set to use cuda:0
#   6%|▌         | 121/2000 [00:16<04:11,  7.47it/s]Device set to use cuda:0
#   6%|▌         | 122/2000 [00:16<04:02,  7.73it/s]Device set to use cuda:0
# Device set to use cuda:0
#   6%|▌         | 124/2000 [00:17<03:37,  8.63it/s]Device set to use cuda:0
# Device set to use cuda:0
#   6%|▋         | 126/2000 [00:17<03:36,  8.65it/s]Device set to use cuda:0
#   6%|▋         | 127/2000 [00:17<03:34,  8.75it/s]Device set to use cuda:0
#   6%|▋         | 128/2000 [00:17<03:35,  8.68it/s]Device set to use cuda:0
#   6%|▋         | 129/2000 [00:17<03:51,  8.10it/s]Device set to use cuda:0
#   6%|▋         | 130/2000 [00:17<03:57,  7.86it/s]Device set to use cuda:0
# Device set to use cuda:0
#   7%|▋         | 132/2000 [00:17<03:33,  8.76it/s]Device set to use cuda:0
#   7%|▋         | 133/2000 [00:18<03:35,  8.66it/s]Device set to use cuda:0
#   7%|▋         | 134/2000 [00:18<03:57,  7.86it/s]Device set to use cuda:0
#   7%|▋         | 135/2000 [00:18<05:22,  5.78it/s]Device set to use cuda:0
#   7%|▋         | 136/2000 [00:18<04:50,  6.42it/s]Device set to use cuda:0
#   7%|▋         | 137/2000 [00:18<04:29,  6.90it/s]Device set to use cuda:0
#   7%|▋         | 138/2000 [00:18<04:54,  6.33it/s]Device set to use cuda:0
# Device set to use cuda:0
#   7%|▋         | 140/2000 [00:19<04:07,  7.51it/s]Device set to use cuda:0
#   7%|▋         | 141/2000 [00:19<04:46,  6.48it/s]Device set to use cuda:0
#   7%|▋         | 142/2000 [00:19<04:51,  6.37it/s]Device set to use cuda:0
#   7%|▋         | 143/2000 [00:19<04:28,  6.92it/s]Device set to use cuda:0
#   7%|▋         | 144/2000 [00:19<04:30,  6.85it/s]Device set to use cuda:0
#   7%|▋         | 145/2000 [00:19<04:26,  6.97it/s]Device set to use cuda:0
#   7%|▋         | 146/2000 [00:20<04:22,  7.07it/s]Device set to use cuda:0
#   7%|▋         | 147/2000 [00:20<04:05,  7.54it/s]Device set to use cuda:0
#   7%|▋         | 148/2000 [00:20<04:15,  7.25it/s]Device set to use cuda:0
# Device set to use cuda:0
#   8%|▊         | 150/2000 [00:20<03:44,  8.23it/s]Device set to use cuda:0
# Device set to use cuda:0
#   8%|▊         | 152/2000 [00:20<03:33,  8.67it/s]Device set to use cuda:0
# Device set to use cuda:0
#   8%|▊         | 154/2000 [00:21<03:32,  8.71it/s]Device set to use cuda:0
# Device set to use cuda:0
#   8%|▊         | 156/2000 [00:21<03:46,  8.16it/s]Device set to use cuda:0
#   8%|▊         | 157/2000 [00:21<03:45,  8.19it/s]Device set to use cuda:0
#   8%|▊         | 158/2000 [00:21<03:55,  7.81it/s]Device set to use cuda:0
#   8%|▊         | 159/2000 [00:21<03:52,  7.91it/s]Device set to use cuda:0
#   8%|▊         | 160/2000 [00:21<03:45,  8.17it/s]Device set to use cuda:0
#   8%|▊         | 161/2000 [00:21<04:13,  7.27it/s]Device set to use cuda:0
#   8%|▊         | 162/2000 [00:22<04:04,  7.53it/s]Device set to use cuda:0
#   8%|▊         | 163/2000 [00:22<03:56,  7.76it/s]Device set to use cuda:0
#   8%|▊         | 164/2000 [00:22<03:51,  7.92it/s]Device set to use cuda:0
#   8%|▊         | 165/2000 [00:22<05:47,  5.28it/s]Device set to use cuda:0
#   8%|▊         | 166/2000 [00:22<05:25,  5.64it/s]Device set to use cuda:0
#   8%|▊         | 167/2000 [00:22<04:47,  6.38it/s]Device set to use cuda:0
#   8%|▊         | 168/2000 [00:23<04:27,  6.84it/s]Device set to use cuda:0
#   8%|▊         | 169/2000 [00:23<04:23,  6.95it/s]Device set to use cuda:0
#   8%|▊         | 170/2000 [00:23<04:05,  7.45it/s]Device set to use cuda:0
#   9%|▊         | 171/2000 [00:23<05:03,  6.03it/s]Device set to use cuda:0
# Device set to use cuda:0
#   9%|▊         | 173/2000 [00:23<04:38,  6.57it/s]Device set to use cuda:0
#   9%|▊         | 174/2000 [00:23<04:36,  6.61it/s]Device set to use cuda:0
#   9%|▉         | 175/2000 [00:24<04:14,  7.16it/s]Device set to use cuda:0
#   9%|▉         | 176/2000 [00:24<04:04,  7.47it/s]Device set to use cuda:0
#   9%|▉         | 177/2000 [00:24<03:50,  7.92it/s]Device set to use cuda:0
#   9%|▉         | 178/2000 [00:24<03:54,  7.78it/s]Device set to use cuda:0
#   9%|▉         | 179/2000 [00:24<04:21,  6.96it/s]Device set to use cuda:0
#   9%|▉         | 180/2000 [00:24<04:25,  6.86it/s]Device set to use cuda:0
#   9%|▉         | 181/2000 [00:24<04:26,  6.82it/s]Device set to use cuda:0
#   9%|▉         | 182/2000 [00:25<04:11,  7.22it/s]Device set to use cuda:0
#   9%|▉         | 183/2000 [00:25<04:01,  7.54it/s]Device set to use cuda:0
# Device set to use cuda:0
#   9%|▉         | 185/2000 [00:25<04:03,  7.44it/s]Device set to use cuda:0
#   9%|▉         | 186/2000 [00:25<04:37,  6.53it/s]Device set to use cuda:0
#   9%|▉         | 187/2000 [00:25<04:58,  6.08it/s]Device set to use cuda:0
#   9%|▉         | 188/2000 [00:26<05:42,  5.29it/s]Device set to use cuda:0
#   9%|▉         | 189/2000 [00:26<05:00,  6.03it/s]Device set to use cuda:0
#  10%|▉         | 190/2000 [00:26<04:37,  6.53it/s]Device set to use cuda:0
#  10%|▉         | 191/2000 [00:26<04:27,  6.75it/s]Device set to use cuda:0
#  10%|▉         | 192/2000 [00:26<04:13,  7.14it/s]Device set to use cuda:0
#  10%|▉         | 193/2000 [00:26<04:27,  6.77it/s]Device set to use cuda:0
#  10%|▉         | 194/2000 [00:26<04:05,  7.34it/s]Device set to use cuda:0
#  10%|▉         | 195/2000 [00:27<04:36,  6.52it/s]Device set to use cuda:0
#  10%|▉         | 196/2000 [00:27<04:35,  6.56it/s]Device set to use cuda:0
#  10%|▉         | 197/2000 [00:27<04:12,  7.15it/s]Device set to use cuda:0
#  10%|▉         | 198/2000 [00:27<04:24,  6.80it/s]Device set to use cuda:0
# Device set to use cuda:0
#  10%|█         | 200/2000 [00:27<03:48,  7.87it/s]Device set to use cuda:0
#  10%|█         | 201/2000 [00:27<03:39,  8.20it/s]Device set to use cuda:0
#  10%|█         | 202/2000 [00:27<03:32,  8.48it/s]Device set to use cuda:0
#  10%|█         | 203/2000 [00:28<03:41,  8.11it/s]Device set to use cuda:0
#  10%|█         | 204/2000 [00:28<03:38,  8.21it/s]Device set to use cuda:0
#  10%|█         | 205/2000 [00:28<03:32,  8.45it/s]Device set to use cuda:0
#  10%|█         | 206/2000 [00:28<03:40,  8.13it/s]Device set to use cuda:0
#  10%|█         | 207/2000 [00:28<03:33,  8.38it/s]Device set to use cuda:0
# Device set to use cuda:0
#  10%|█         | 209/2000 [00:28<03:21,  8.87it/s]Device set to use cuda:0
#  10%|█         | 210/2000 [00:28<03:32,  8.41it/s]Device set to use cuda:0
#  11%|█         | 211/2000 [00:29<04:01,  7.40it/s]Device set to use cuda:0
#  11%|█         | 212/2000 [00:29<03:53,  7.67it/s]Device set to use cuda:0
#  11%|█         | 213/2000 [00:29<03:43,  8.00it/s]Device set to use cuda:0
#  11%|█         | 214/2000 [00:29<04:25,  6.72it/s]Device set to use cuda:0
#  11%|█         | 215/2000 [00:29<04:10,  7.13it/s]Device set to use cuda:0
#  11%|█         | 216/2000 [00:29<03:52,  7.67it/s]Device set to use cuda:0
#  11%|█         | 217/2000 [00:29<03:40,  8.10it/s]Device set to use cuda:0
#  11%|█         | 218/2000 [00:29<04:15,  6.96it/s]Device set to use cuda:0
#  11%|█         | 219/2000 [00:30<04:20,  6.83it/s]Device set to use cuda:0
#  11%|█         | 220/2000 [00:30<04:05,  7.25it/s]Device set to use cuda:0
#  11%|█         | 221/2000 [00:30<04:05,  7.25it/s]Device set to use cuda:0
#  11%|█         | 222/2000 [00:30<04:05,  7.26it/s]Device set to use cuda:0
#  11%|█         | 223/2000 [00:30<03:48,  7.76it/s]Device set to use cuda:0
#  11%|█         | 224/2000 [00:30<03:50,  7.71it/s]Device set to use cuda:0
#  11%|█▏        | 225/2000 [00:30<03:52,  7.62it/s]Device set to use cuda:0
#  11%|█▏        | 226/2000 [00:31<04:12,  7.04it/s]Device set to use cuda:0
#  11%|█▏        | 227/2000 [00:31<04:00,  7.39it/s]Device set to use cuda:0
#  11%|█▏        | 228/2000 [00:31<03:46,  7.81it/s]Device set to use cuda:0
#  11%|█▏        | 229/2000 [00:31<04:07,  7.16it/s]Device set to use cuda:0
#  12%|█▏        | 230/2000 [00:31<04:42,  6.26it/s]Device set to use cuda:0
#  12%|█▏        | 231/2000 [00:31<04:20,  6.79it/s]Device set to use cuda:0
#  12%|█▏        | 232/2000 [00:32<05:17,  5.57it/s]Device set to use cuda:0
#  12%|█▏        | 233/2000 [00:32<04:40,  6.29it/s]Device set to use cuda:0
#  12%|█▏        | 234/2000 [00:32<04:15,  6.90it/s]Device set to use cuda:0
#  12%|█▏        | 235/2000 [00:32<04:01,  7.30it/s]Device set to use cuda:0
#  12%|█▏        | 236/2000 [00:32<04:01,  7.32it/s]Device set to use cuda:0
#  12%|█▏        | 237/2000 [00:32<03:51,  7.61it/s]Device set to use cuda:0
#  12%|█▏        | 238/2000 [00:32<04:17,  6.84it/s]Device set to use cuda:0
# Device set to use cuda:0
#  12%|█▏        | 240/2000 [00:33<03:40,  7.97it/s]Device set to use cuda:0
# Device set to use cuda:0
#  12%|█▏        | 242/2000 [00:33<03:44,  7.82it/s]Device set to use cuda:0
#  12%|█▏        | 243/2000 [00:33<03:41,  7.93it/s]Device set to use cuda:0
#  12%|█▏        | 244/2000 [00:33<03:34,  8.19it/s]Device set to use cuda:0
#  12%|█▏        | 245/2000 [00:33<03:32,  8.25it/s]Device set to use cuda:0
#  12%|█▏        | 246/2000 [00:33<03:27,  8.47it/s]Device set to use cuda:0
#  12%|█▏        | 247/2000 [00:33<03:27,  8.45it/s]Device set to use cuda:0
#  12%|█▏        | 248/2000 [00:33<03:28,  8.40it/s]Device set to use cuda:0
#  12%|█▏        | 249/2000 [00:34<03:35,  8.13it/s]Device set to use cuda:0
#  12%|█▎        | 250/2000 [00:34<04:05,  7.14it/s]Device set to use cuda:0
#  13%|█▎        | 251/2000 [00:34<03:49,  7.63it/s]Device set to use cuda:0
# Device set to use cuda:0
#  13%|█▎        | 253/2000 [00:34<03:30,  8.32it/s]Device set to use cuda:0
#  13%|█▎        | 254/2000 [00:34<03:37,  8.04it/s]Device set to use cuda:0
#  13%|█▎        | 255/2000 [00:34<03:41,  7.89it/s]Device set to use cuda:0
#  13%|█▎        | 256/2000 [00:35<03:37,  8.01it/s]Device set to use cuda:0
#  13%|█▎        | 257/2000 [00:35<04:12,  6.91it/s]Device set to use cuda:0
#  13%|█▎        | 258/2000 [00:35<04:21,  6.66it/s]Device set to use cuda:0
#  13%|█▎        | 259/2000 [00:35<04:15,  6.81it/s]Device set to use cuda:0
#  13%|█▎        | 260/2000 [00:35<03:57,  7.33it/s]Device set to use cuda:0
#  13%|█▎        | 261/2000 [00:35<03:48,  7.61it/s]Device set to use cuda:0
#  13%|█▎        | 262/2000 [00:36<05:15,  5.51it/s]Device set to use cuda:0
#  13%|█▎        | 263/2000 [00:36<04:38,  6.23it/s]Device set to use cuda:0
# Device set to use cuda:0
#  13%|█▎        | 265/2000 [00:36<04:36,  6.27it/s]Device set to use cuda:0
#  13%|█▎        | 266/2000 [00:36<04:18,  6.70it/s]Device set to use cuda:0
# Device set to use cuda:0
#  13%|█▎        | 268/2000 [00:36<04:49,  5.99it/s]Device set to use cuda:0
#  13%|█▎        | 269/2000 [00:37<04:36,  6.26it/s]Device set to use cuda:0
#  14%|█▎        | 270/2000 [00:37<04:13,  6.82it/s]Device set to use cuda:0
# Device set to use cuda:0
#  14%|█▎        | 272/2000 [00:37<03:47,  7.60it/s]Device set to use cuda:0
#  14%|█▎        | 273/2000 [00:37<04:11,  6.86it/s]Device set to use cuda:0
#  14%|█▎        | 274/2000 [00:37<04:00,  7.19it/s]Device set to use cuda:0
#  14%|█▍        | 275/2000 [00:37<03:50,  7.48it/s]Device set to use cuda:0
#  14%|█▍        | 276/2000 [00:38<04:31,  6.34it/s]Device set to use cuda:0
# Device set to use cuda:0
#  14%|█▍        | 278/2000 [00:38<03:54,  7.35it/s]Device set to use cuda:0
#  14%|█▍        | 279/2000 [00:38<03:53,  7.37it/s]Device set to use cuda:0
#  14%|█▍        | 280/2000 [00:38<04:44,  6.04it/s]Device set to use cuda:0
#  14%|█▍        | 281/2000 [00:38<04:31,  6.34it/s]Device set to use cuda:0
#  14%|█▍        | 282/2000 [00:38<04:12,  6.80it/s]Device set to use cuda:0
#  14%|█▍        | 283/2000 [00:39<03:58,  7.19it/s]Device set to use cuda:0
#  14%|█▍        | 284/2000 [00:39<03:55,  7.28it/s]Device set to use cuda:0
#  14%|█▍        | 285/2000 [00:39<03:42,  7.71it/s]Device set to use cuda:0
# Device set to use cuda:0
#  14%|█▍        | 287/2000 [00:39<03:24,  8.36it/s]Device set to use cuda:0
#  14%|█▍        | 288/2000 [00:39<03:23,  8.40it/s]Device set to use cuda:0
#  14%|█▍        | 289/2000 [00:39<03:23,  8.41it/s]Device set to use cuda:0
#  14%|█▍        | 290/2000 [00:39<03:19,  8.59it/s]Device set to use cuda:0
#  15%|█▍        | 291/2000 [00:40<03:46,  7.53it/s]Device set to use cuda:0
#  15%|█▍        | 292/2000 [00:40<04:29,  6.34it/s]Device set to use cuda:0
#  15%|█▍        | 293/2000 [00:40<04:27,  6.39it/s]Device set to use cuda:0
#  15%|█▍        | 294/2000 [00:40<04:24,  6.46it/s]Device set to use cuda:0
#  15%|█▍        | 295/2000 [00:40<04:05,  6.93it/s]Device set to use cuda:0
# Device set to use cuda:0
#  15%|█▍        | 297/2000 [00:40<04:04,  6.96it/s]Device set to use cuda:0
#  15%|█▍        | 298/2000 [00:41<03:55,  7.22it/s]Device set to use cuda:0
#  15%|█▍        | 299/2000 [00:41<04:13,  6.71it/s]Device set to use cuda:0
#  15%|█▌        | 300/2000 [00:41<04:07,  6.88it/s]Device set to use cuda:0
#  15%|█▌        | 301/2000 [00:41<03:54,  7.25it/s]Device set to use cuda:0
#  15%|█▌        | 302/2000 [00:41<03:46,  7.49it/s]Device set to use cuda:0
# Device set to use cuda:0
#  15%|█▌        | 304/2000 [00:41<04:18,  6.56it/s]Device set to use cuda:0
#  15%|█▌        | 305/2000 [00:42<04:05,  6.92it/s]Device set to use cuda:0
#  15%|█▌        | 306/2000 [00:42<04:13,  6.68it/s]Device set to use cuda:0
#  15%|█▌        | 307/2000 [00:42<04:05,  6.89it/s]Device set to use cuda:0
#  15%|█▌        | 308/2000 [00:42<03:54,  7.22it/s]Device set to use cuda:0
#  15%|█▌        | 309/2000 [00:42<04:14,  6.64it/s]Device set to use cuda:0
#  16%|█▌        | 310/2000 [00:42<04:15,  6.62it/s]Device set to use cuda:0
#  16%|█▌        | 311/2000 [00:42<03:58,  7.07it/s]Device set to use cuda:0
#  16%|█▌        | 312/2000 [00:43<03:44,  7.53it/s]Device set to use cuda:0
#  16%|█▌        | 313/2000 [00:43<03:38,  7.74it/s]Device set to use cuda:0
#  16%|█▌        | 314/2000 [00:43<03:40,  7.65it/s]Device set to use cuda:0
#  16%|█▌        | 315/2000 [00:43<03:35,  7.81it/s]Device set to use cuda:0
#  16%|█▌        | 316/2000 [00:43<03:54,  7.17it/s]Device set to use cuda:0
#  16%|█▌        | 317/2000 [00:43<03:40,  7.64it/s]Device set to use cuda:0
#  16%|█▌        | 318/2000 [00:43<03:33,  7.86it/s]Device set to use cuda:0
#  16%|█▌        | 319/2000 [00:43<03:30,  8.00it/s]Device set to use cuda:0
#  16%|█▌        | 320/2000 [00:44<03:28,  8.08it/s]Device set to use cuda:0
#  16%|█▌        | 321/2000 [00:44<03:41,  7.57it/s]Device set to use cuda:0
#  16%|█▌        | 322/2000 [00:44<03:34,  7.81it/s]Device set to use cuda:0
#  16%|█▌        | 323/2000 [00:44<03:37,  7.69it/s]Device set to use cuda:0
#  16%|█▌        | 324/2000 [00:44<03:54,  7.15it/s]Device set to use cuda:0
#  16%|█▋        | 325/2000 [00:44<03:51,  7.22it/s]Device set to use cuda:0
#  16%|█▋        | 326/2000 [00:44<03:36,  7.72it/s]Device set to use cuda:0
#  16%|█▋        | 327/2000 [00:45<05:25,  5.14it/s]Device set to use cuda:0
# Device set to use cuda:0
#  16%|█▋        | 329/2000 [00:45<04:30,  6.18it/s]Device set to use cuda:0
#  16%|█▋        | 330/2000 [00:45<04:26,  6.26it/s]Device set to use cuda:0
#  17%|█▋        | 331/2000 [00:45<04:03,  6.84it/s]Device set to use cuda:0
#  17%|█▋        | 332/2000 [00:45<03:59,  6.97it/s]Device set to use cuda:0
#  17%|█▋        | 333/2000 [00:46<04:09,  6.68it/s]Device set to use cuda:0
#  17%|█▋        | 334/2000 [00:46<05:15,  5.27it/s]Device set to use cuda:0
#  17%|█▋        | 335/2000 [00:46<04:36,  6.03it/s]Device set to use cuda:0
#  17%|█▋        | 336/2000 [00:46<04:22,  6.34it/s]Device set to use cuda:0
#  17%|█▋        | 337/2000 [00:46<04:03,  6.84it/s]Device set to use cuda:0
#  17%|█▋        | 338/2000 [00:46<03:57,  6.99it/s]Device set to use cuda:0
#  17%|█▋        | 339/2000 [00:46<03:46,  7.34it/s]Device set to use cuda:0
#  17%|█▋        | 340/2000 [00:47<03:59,  6.93it/s]Device set to use cuda:0
#  17%|█▋        | 341/2000 [00:47<03:46,  7.32it/s]Device set to use cuda:0
#  17%|█▋        | 342/2000 [00:47<03:39,  7.57it/s]Device set to use cuda:0
#  17%|█▋        | 343/2000 [00:47<05:20,  5.17it/s]Device set to use cuda:0
#  17%|█▋        | 344/2000 [00:47<05:15,  5.25it/s]Device set to use cuda:0
# Device set to use cuda:0
#  17%|█▋        | 346/2000 [00:48<04:41,  5.87it/s]Device set to use cuda:0
#  17%|█▋        | 347/2000 [00:48<04:26,  6.20it/s]Device set to use cuda:0
#  17%|█▋        | 348/2000 [00:48<04:08,  6.66it/s]Device set to use cuda:0
#  17%|█▋        | 349/2000 [00:48<04:15,  6.47it/s]Device set to use cuda:0
#  90%|████████▉ | 1797/2000 [04:19<00:30,  6.62it/s]Device set to use cuda:0
#  90%|████████▉ | 1798/2000 [04:19<00:28,  7.07it/s]Device set to use cuda:0
#  90%|████████▉ | 1799/2000 [04:19<00:31,  6.33it/s]Device set to use cuda:0
#  90%|█████████ | 1800/2000 [04:19<00:28,  6.98it/s]Device set to use cuda:0
#  90%|█████████ | 1801/2000 [04:19<00:27,  7.11it/s]Device set to use cuda:0
#  90%|█████████ | 1802/2000 [04:19<00:26,  7.59it/s]Device set to use cuda:0
#  90%|█████████ | 1803/2000 [04:19<00:24,  8.05it/s]Device set to use cuda:0
#  90%|█████████ | 1804/2000 [04:20<00:22,  8.54it/s]Device set to use cuda:0
#  90%|█████████ | 1805/2000 [04:20<00:22,  8.70it/s]Device set to use cuda:0
#  90%|█████████ | 1806/2000 [04:20<00:27,  6.94it/s]Device set to use cuda:0
#  90%|█████████ | 1807/2000 [04:20<00:26,  7.27it/s]Device set to use cuda:0
#  90%|█████████ | 1808/2000 [04:20<00:25,  7.53it/s]Device set to use cuda:0
#  90%|█████████ | 1809/2000 [04:20<00:24,  7.95it/s]Device set to use cuda:0
#  90%|█████████ | 1810/2000 [04:20<00:23,  8.20it/s]Device set to use cuda:0
#  91%|█████████ | 1811/2000 [04:20<00:22,  8.22it/s]Device set to use cuda:0
#  91%|█████████ | 1812/2000 [04:21<00:27,  6.75it/s]Device set to use cuda:0
#  91%|█████████ | 1813/2000 [04:21<00:26,  6.94it/s]Device set to use cuda:0
# Device set to use cuda:0
#  91%|█████████ | 1815/2000 [04:21<00:24,  7.68it/s]Device set to use cuda:0
#  91%|█████████ | 1816/2000 [04:21<00:27,  6.80it/s]Device set to use cuda:0
#  91%|█████████ | 1817/2000 [04:21<00:26,  6.91it/s]Device set to use cuda:0
#  91%|█████████ | 1818/2000 [04:22<00:27,  6.67it/s]Device set to use cuda:0
#  91%|█████████ | 1819/2000 [04:22<00:27,  6.63it/s]Device set to use cuda:0
#  91%|█████████ | 1820/2000 [04:22<00:27,  6.63it/s]Device set to use cuda:0
# Device set to use cuda:0
#  91%|█████████ | 1822/2000 [04:22<00:23,  7.63it/s]Device set to use cuda:0
# Device set to use cuda:0
#  91%|█████████ | 1824/2000 [04:22<00:23,  7.64it/s]Device set to use cuda:0
#  91%|█████████▏| 1825/2000 [04:22<00:23,  7.55it/s]Device set to use cuda:0
#  91%|█████████▏| 1826/2000 [04:23<00:22,  7.73it/s]Device set to use cuda:0
#  91%|█████████▏| 1827/2000 [04:23<00:21,  7.90it/s]Device set to use cuda:0
#  91%|█████████▏| 1828/2000 [04:23<00:24,  7.06it/s]Device set to use cuda:0
#  91%|█████████▏| 1829/2000 [04:23<00:24,  7.09it/s]Device set to use cuda:0
#  92%|█████████▏| 1830/2000 [04:23<00:22,  7.54it/s]Device set to use cuda:0
#  92%|█████████▏| 1831/2000 [04:23<00:21,  7.91it/s]Device set to use cuda:0
#  92%|█████████▏| 1832/2000 [04:23<00:21,  7.71it/s]Device set to use cuda:0
#  92%|█████████▏| 1833/2000 [04:24<00:22,  7.33it/s]Device set to use cuda:0
#  92%|█████████▏| 1834/2000 [04:24<00:21,  7.61it/s]Device set to use cuda:0
#  92%|█████████▏| 1835/2000 [04:24<00:20,  8.01it/s]Device set to use cuda:0
#  92%|█████████▏| 1836/2000 [04:24<00:20,  8.13it/s]Device set to use cuda:0
#  92%|█████████▏| 1837/2000 [04:24<00:23,  6.89it/s]Device set to use cuda:0
# Device set to use cuda:0
#  92%|█████████▏| 1839/2000 [04:24<00:21,  7.57it/s]Device set to use cuda:0
#  92%|█████████▏| 1840/2000 [04:24<00:20,  7.87it/s]Device set to use cuda:0
#  92%|█████████▏| 1841/2000 [04:25<00:29,  5.38it/s]Device set to use cuda:0
#  92%|█████████▏| 1842/2000 [04:25<00:27,  5.81it/s]Device set to use cuda:0
#  92%|█████████▏| 1843/2000 [04:25<00:24,  6.34it/s]Device set to use cuda:0
#  92%|█████████▏| 1844/2000 [04:25<00:22,  6.94it/s]Device set to use cuda:0
#  92%|█████████▏| 1845/2000 [04:25<00:21,  7.06it/s]Device set to use cuda:0
#  92%|█████████▏| 1846/2000 [04:25<00:20,  7.40it/s]Device set to use cuda:0
#  92%|█████████▏| 1847/2000 [04:25<00:19,  7.84it/s]Device set to use cuda:0
#  92%|█████████▏| 1848/2000 [04:26<00:18,  8.12it/s]Device set to use cuda:0
#  92%|█████████▏| 1849/2000 [04:26<00:18,  8.19it/s]Device set to use cuda:0
#  92%|█████████▎| 1850/2000 [04:26<00:21,  6.96it/s]Device set to use cuda:0
#  93%|█████████▎| 1851/2000 [04:26<00:21,  6.85it/s]Device set to use cuda:0
#  93%|█████████▎| 1852/2000 [04:26<00:19,  7.42it/s]Device set to use cuda:0
#  93%|█████████▎| 1853/2000 [04:26<00:23,  6.35it/s]Device set to use cuda:0
#  93%|█████████▎| 1854/2000 [04:27<00:31,  4.63it/s]Device set to use cuda:0
#  93%|█████████▎| 1855/2000 [04:27<00:26,  5.41it/s]Device set to use cuda:0
#  93%|█████████▎| 1856/2000 [04:27<00:23,  6.04it/s]Device set to use cuda:0
#  93%|█████████▎| 1857/2000 [04:27<00:22,  6.36it/s]Device set to use cuda:0
#  93%|█████████▎| 1858/2000 [04:27<00:21,  6.63it/s]Device set to use cuda:0
#  93%|█████████▎| 1859/2000 [04:27<00:20,  6.88it/s]Device set to use cuda:0
#  93%|█████████▎| 1860/2000 [04:27<00:19,  7.24it/s]Device set to use cuda:0
#  93%|█████████▎| 1861/2000 [04:28<00:20,  6.79it/s]Device set to use cuda:0
#  93%|█████████▎| 1862/2000 [04:28<00:22,  6.16it/s]Device set to use cuda:0
#  93%|█████████▎| 1863/2000 [04:28<00:20,  6.78it/s]Device set to use cuda:0
#  93%|█████████▎| 1864/2000 [04:28<00:19,  6.96it/s]Device set to use cuda:0
#  93%|█████████▎| 1865/2000 [04:28<00:23,  5.81it/s]Device set to use cuda:0
#  93%|█████████▎| 1866/2000 [04:28<00:20,  6.39it/s]Device set to use cuda:0
#  93%|█████████▎| 1867/2000 [04:29<00:20,  6.65it/s]Device set to use cuda:0
#  93%|█████████▎| 1868/2000 [04:29<00:18,  7.10it/s]Device set to use cuda:0
#  93%|█████████▎| 1869/2000 [04:29<00:19,  6.71it/s]Device set to use cuda:0
#  94%|█████████▎| 1870/2000 [04:29<00:23,  5.49it/s]Device set to use cuda:0
#  94%|█████████▎| 1871/2000 [04:29<00:22,  5.80it/s]Device set to use cuda:0
#  94%|█████████▎| 1872/2000 [04:29<00:19,  6.54it/s]Device set to use cuda:0
#  94%|█████████▎| 1873/2000 [04:30<00:17,  7.15it/s]Device set to use cuda:0
#  94%|█████████▎| 1874/2000 [04:30<00:17,  7.18it/s]Device set to use cuda:0
#  94%|█████████▍| 1875/2000 [04:30<00:20,  6.07it/s]Device set to use cuda:0
#  94%|█████████▍| 1876/2000 [04:30<00:18,  6.59it/s]Device set to use cuda:0
#  94%|█████████▍| 1877/2000 [04:30<00:17,  7.01it/s]Device set to use cuda:0
#  94%|█████████▍| 1878/2000 [04:30<00:16,  7.38it/s]Device set to use cuda:0
#  94%|█████████▍| 1879/2000 [04:30<00:19,  6.17it/s]Device set to use cuda:0
#  94%|█████████▍| 1880/2000 [04:31<00:21,  5.65it/s]Device set to use cuda:0
#  94%|█████████▍| 1881/2000 [04:31<00:19,  6.08it/s]Device set to use cuda:0
#  94%|█████████▍| 1882/2000 [04:31<00:17,  6.74it/s]Device set to use cuda:0
#  94%|█████████▍| 1883/2000 [04:31<00:16,  7.15it/s]Device set to use cuda:0
#  94%|█████████▍| 1884/2000 [04:31<00:16,  7.18it/s]Device set to use cuda:0
#  94%|█████████▍| 1885/2000 [04:31<00:18,  6.09it/s]Device set to use cuda:0
#  94%|█████████▍| 1886/2000 [04:32<00:17,  6.42it/s]Device set to use cuda:0
#  94%|█████████▍| 1887/2000 [04:32<00:16,  7.02it/s]Device set to use cuda:0
#  94%|█████████▍| 1888/2000 [04:32<00:17,  6.30it/s]Device set to use cuda:0
#  94%|█████████▍| 1889/2000 [04:32<00:16,  6.55it/s]Device set to use cuda:0
#  94%|█████████▍| 1890/2000 [04:32<00:16,  6.81it/s]Device set to use cuda:0
# Device set to use cuda:0
#  95%|█████████▍| 1892/2000 [04:32<00:15,  6.99it/s]Device set to use cuda:0
#  95%|█████████▍| 1893/2000 [04:33<00:14,  7.38it/s]Device set to use cuda:0
#  95%|█████████▍| 1894/2000 [04:33<00:13,  7.59it/s]Device set to use cuda:0
#  95%|█████████▍| 1895/2000 [04:33<00:17,  6.00it/s]Device set to use cuda:0
#  95%|█████████▍| 1896/2000 [04:33<00:22,  4.67it/s]Device set to use cuda:0
#  95%|█████████▍| 1897/2000 [04:33<00:19,  5.42it/s]Device set to use cuda:0
#  95%|█████████▍| 1898/2000 [04:33<00:16,  6.04it/s]Device set to use cuda:0
#  95%|█████████▍| 1899/2000 [04:34<00:15,  6.55it/s]Device set to use cuda:0
#  95%|█████████▌| 1900/2000 [04:34<00:15,  6.37it/s]Device set to use cuda:0
#  95%|█████████▌| 1901/2000 [04:34<00:14,  6.84it/s]Device set to use cuda:0
#  95%|█████████▌| 1902/2000 [04:34<00:20,  4.83it/s]Device set to use cuda:0
#  95%|█████████▌| 1903/2000 [04:34<00:17,  5.39it/s]Device set to use cuda:0
#  95%|█████████▌| 1904/2000 [04:34<00:16,  5.84it/s]Device set to use cuda:0
#  95%|█████████▌| 1905/2000 [04:35<00:15,  6.06it/s]Device set to use cuda:0
# Device set to use cuda:0
#  95%|█████████▌| 1907/2000 [04:35<00:12,  7.52it/s]Device set to use cuda:0
#  95%|█████████▌| 1908/2000 [04:35<00:12,  7.53it/s]Device set to use cuda:0
#  95%|█████████▌| 1909/2000 [04:35<00:14,  6.08it/s]Device set to use cuda:0
#  96%|█████████▌| 1910/2000 [04:35<00:16,  5.41it/s]Device set to use cuda:0
#  96%|█████████▌| 1911/2000 [04:36<00:14,  6.01it/s]Device set to use cuda:0
#  96%|█████████▌| 1912/2000 [04:36<00:15,  5.85it/s]Device set to use cuda:0
#  96%|█████████▌| 1913/2000 [04:36<00:13,  6.50it/s]Device set to use cuda:0
#  96%|█████████▌| 1914/2000 [04:36<00:12,  7.08it/s]Device set to use cuda:0
#  96%|█████████▌| 1915/2000 [04:36<00:14,  5.69it/s]Device set to use cuda:0
#  96%|█████████▌| 1916/2000 [04:36<00:15,  5.27it/s]Device set to use cuda:0
#  96%|█████████▌| 1917/2000 [04:37<00:14,  5.91it/s]Device set to use cuda:0
#  96%|█████████▌| 1918/2000 [04:37<00:16,  5.10it/s]Device set to use cuda:0
#  96%|█████████▌| 1919/2000 [04:37<00:15,  5.09it/s]Device set to use cuda:0
#  96%|█████████▌| 1920/2000 [04:37<00:15,  5.23it/s]Device set to use cuda:0
#  96%|█████████▌| 1921/2000 [04:37<00:13,  5.69it/s]Device set to use cuda:0
#  96%|█████████▌| 1922/2000 [04:38<00:14,  5.36it/s]Device set to use cuda:0
#  96%|█████████▌| 1923/2000 [04:38<00:12,  5.97it/s]Device set to use cuda:0
#  96%|█████████▌| 1924/2000 [04:38<00:11,  6.52it/s]Device set to use cuda:0
# Device set to use cuda:0
#  96%|█████████▋| 1926/2000 [04:38<00:11,  6.43it/s]Device set to use cuda:0
#  96%|█████████▋| 1927/2000 [04:38<00:12,  6.05it/s]Device set to use cuda:0
#  96%|█████████▋| 1928/2000 [04:38<00:11,  6.52it/s]Device set to use cuda:0
#  96%|█████████▋| 1929/2000 [04:39<00:10,  7.05it/s]Device set to use cuda:0
#  96%|█████████▋| 1930/2000 [04:39<00:09,  7.50it/s]Device set to use cuda:0
#  97%|█████████▋| 1931/2000 [04:39<00:09,  7.22it/s]Device set to use cuda:0
#  97%|█████████▋| 1932/2000 [04:39<00:09,  7.51it/s]Device set to use cuda:0
#  97%|█████████▋| 1933/2000 [04:39<00:09,  7.22it/s]Device set to use cuda:0
#  97%|█████████▋| 1934/2000 [04:39<00:09,  7.25it/s]Device set to use cuda:0
#  97%|█████████▋| 1935/2000 [04:40<00:13,  4.97it/s]Device set to use cuda:0
#  97%|█████████▋| 1936/2000 [04:40<00:11,  5.70it/s]Device set to use cuda:0
#  97%|█████████▋| 1937/2000 [04:40<00:11,  5.36it/s]Device set to use cuda:0
#  97%|█████████▋| 1938/2000 [04:40<00:10,  6.09it/s]Device set to use cuda:0
#  97%|█████████▋| 1939/2000 [04:40<00:08,  6.81it/s]Device set to use cuda:0
#  97%|█████████▋| 1940/2000 [04:40<00:08,  7.23it/s]Device set to use cuda:0
#  97%|█████████▋| 1941/2000 [04:40<00:08,  7.31it/s]Device set to use cuda:0
#  97%|█████████▋| 1942/2000 [04:41<00:08,  6.70it/s]Device set to use cuda:0
# Device set to use cuda:0
#  97%|█████████▋| 1944/2000 [04:41<00:07,  7.70it/s]Device set to use cuda:0
#  97%|█████████▋| 1945/2000 [04:41<00:07,  7.65it/s]Device set to use cuda:0
#  97%|█████████▋| 1946/2000 [04:41<00:08,  6.43it/s]Device set to use cuda:0
#  97%|█████████▋| 1947/2000 [04:41<00:07,  6.68it/s]Device set to use cuda:0
#  97%|█████████▋| 1948/2000 [04:41<00:07,  7.08it/s]Device set to use cuda:0
# Device set to use cuda:0
#  98%|█████████▊| 1950/2000 [04:42<00:06,  8.29it/s]Device set to use cuda:0
#  98%|█████████▊| 1951/2000 [04:42<00:05,  8.32it/s]Device set to use cuda:0
#  98%|█████████▊| 1952/2000 [04:42<00:05,  8.08it/s]Device set to use cuda:0
#  98%|█████████▊| 1953/2000 [04:42<00:06,  7.23it/s]Device set to use cuda:0
#  98%|█████████▊| 1954/2000 [04:42<00:06,  7.46it/s]Device set to use cuda:0
#  98%|█████████▊| 1955/2000 [04:42<00:06,  7.46it/s]Device set to use cuda:0
#  98%|█████████▊| 1956/2000 [04:42<00:05,  7.66it/s]Device set to use cuda:0
#  98%|█████████▊| 1957/2000 [04:43<00:05,  7.82it/s]Device set to use cuda:0
#  98%|█████████▊| 1958/2000 [04:43<00:05,  7.65it/s]Device set to use cuda:0
#  98%|█████████▊| 1959/2000 [04:43<00:05,  8.05it/s]Device set to use cuda:0
#  98%|█████████▊| 1960/2000 [04:43<00:05,  7.16it/s]Device set to use cuda:0
#  98%|█████████▊| 1961/2000 [04:43<00:05,  7.65it/s]Device set to use cuda:0
#  98%|█████████▊| 1962/2000 [04:43<00:04,  8.00it/s]Device set to use cuda:0
#  98%|█████████▊| 1963/2000 [04:43<00:04,  8.29it/s]Device set to use cuda:0
#  98%|█████████▊| 1964/2000 [04:43<00:04,  8.35it/s]Device set to use cuda:0
#  98%|█████████▊| 1965/2000 [04:44<00:04,  7.02it/s]Device set to use cuda:0
#  98%|█████████▊| 1966/2000 [04:44<00:05,  6.27it/s]Device set to use cuda:0
#  98%|█████████▊| 1967/2000 [04:44<00:04,  6.77it/s]Device set to use cuda:0
#  98%|█████████▊| 1968/2000 [04:44<00:04,  7.18it/s]Device set to use cuda:0
#  98%|█████████▊| 1969/2000 [04:44<00:05,  5.42it/s]Device set to use cuda:0
#  98%|█████████▊| 1970/2000 [04:44<00:04,  6.06it/s]Device set to use cuda:0
#  99%|█████████▊| 1971/2000 [04:45<00:04,  6.70it/s]Device set to use cuda:0
#  99%|█████████▊| 1972/2000 [04:45<00:03,  7.12it/s]Device set to use cuda:0
#  99%|█████████▊| 1973/2000 [04:45<00:03,  7.42it/s]Device set to use cuda:0
#  99%|█████████▊| 1974/2000 [04:45<00:03,  7.65it/s]Device set to use cuda:0
#  99%|█████████▉| 1975/2000 [04:45<00:03,  7.34it/s]Device set to use cuda:0
#  99%|█████████▉| 1976/2000 [04:45<00:03,  7.30it/s]Device set to use cuda:0
#  99%|█████████▉| 1977/2000 [04:45<00:02,  7.74it/s]Device set to use cuda:0
#  99%|█████████▉| 1978/2000 [04:45<00:02,  8.14it/s]Device set to use cuda:0
# Device set to use cuda:0
#  99%|█████████▉| 1980/2000 [04:46<00:02,  8.62it/s]Device set to use cuda:0
#  99%|█████████▉| 1981/2000 [04:46<00:02,  8.54it/s]Device set to use cuda:0
#  99%|█████████▉| 1982/2000 [04:46<00:02,  8.51it/s]Device set to use cuda:0
#  99%|█████████▉| 1983/2000 [04:46<00:02,  6.96it/s]Device set to use cuda:0
#  99%|█████████▉| 1984/2000 [04:46<00:02,  7.42it/s]Device set to use cuda:0
#  99%|█████████▉| 1985/2000 [04:46<00:02,  7.42it/s]Device set to use cuda:0
#  99%|█████████▉| 1986/2000 [04:46<00:01,  7.18it/s]Device set to use cuda:0
#  99%|█████████▉| 1987/2000 [04:47<00:02,  6.39it/s]Device set to use cuda:0
#  99%|█████████▉| 1988/2000 [04:47<00:02,  5.79it/s]Device set to use cuda:0
#  99%|█████████▉| 1989/2000 [04:47<00:01,  6.00it/s]Device set to use cuda:0
# 100%|█████████▉| 1990/2000 [04:47<00:01,  5.88it/s]Device set to use cuda:0
# 100%|█████████▉| 1991/2000 [04:47<00:01,  6.46it/s]Device set to use cuda:0
# 100%|█████████▉| 1992/2000 [04:47<00:01,  7.04it/s]Device set to use cuda:0
# 100%|█████████▉| 1993/2000 [04:48<00:00,  7.53it/s]Device set to use cuda:0
# 100%|█████████▉| 1994/2000 [04:48<00:00,  6.55it/s]Device set to use cuda:0
# 100%|█████████▉| 1995/2000 [04:48<00:00,  6.38it/s]Device set to use cuda:0
# 100%|█████████▉| 1996/2000 [04:48<00:00,  5.64it/s]Device set to use cuda:0
# Device set to use cuda:0
# 100%|█████████▉| 1998/2000 [04:48<00:00,  6.12it/s]Device set to use cuda:0
# 100%|█████████▉| 1999/2000 [04:49<00:00,  5.96it/s]Device set to use cuda:0
# 100%|██████████| 2000/2000 [04:49<00:00,  6.91it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 6
#       4 y_true = ["positive" if label == 1 else "negative" for label in y_true]
#       5 y_pred = predict(test_dataset, model, tokenizer)
# ----> 6 evaluate(y_true, y_pred)
#
# NameError: name 'evaluate' is not defined

# %%
evaluate(y_true, y_pred)
# Out:
# Accuracy: 0.963
# Accuracy for label positive: 0.973
# Accuracy for label negative: 0.952
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     positive       0.95      0.97      0.96      1006
#     negative       0.97      0.95      0.96       994
#
#     accuracy                           0.96      2000
#    macro avg       0.96      0.96      0.96      2000
# weighted avg       0.96      0.96      0.96      2000
#
#
# Confusion Matrix:
# [[979  27]
#  [ 48 946]]
