# %% [markdown]
# # finetuning llama 3.2 3b for text classification (imdb reviews)
#
# in this tutorial, we will finetune a llama 3.2 3b model for text classification on the imdb movie reviews dataset.
#
# llama is an open-source, autoregressive, large language model and can be finetuned for various tasks including text classification.
#
# we will use parameter efficient finetuning (PEFT) to finetune the model using low-rank adaptation (LoRA). this technique allows us to finetune the model with a small number of parameters instead of the full model, making it more efficient and cost-effective.
#
# after finetuning, we can store only the LoRA parameters, which are much smaller than the full model parameters.
#
# this tutorial is based on the following online [tutorial](https://www.kaggle.com/code/ma2323/llama-3-2-3b-finetuning-imdb-reviews)

# %% [markdown]
# first step is to acquire the liscence to use the model weights. you can do this on huggingface, meta or kaggle. it requires minimal information about the user. once you have the liscence, you can download the model weights from the model hub. in this tutorial, we will use the llama 3.2 3b model from huggingface.

# %% [markdown]
# the packages we will use for this tutorial are:
#
# - transformers
# - accelerate
# - bitsandbytes
# - peft
# - trl
#
# make sure to install these packages before running the code.
#
# ```bash
# pip install transformers accelerate bitsandbytes peft trl
# ```
#
# we will use the `transformers` library to load the llama 3.2 3b model and finetune it for text classification.
#
# the `accelerate` library will help us manage the training process and use the GPU for faster training.
#
# the `bitsandbytes` library will help us load the model with 8-bit quantization, which is more efficient than full 32-bit precision.

# %%
import os
from dotenv import load_dotenv

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

load_dotenv()

HF_token = os.getenv("HF_token")
CACHE_DIR = os.getenv("CACHE_DIR")
OUTPUT_DIR = "./llama_finetuned"
WANDB_PROJECT = "llama-imdb-finetuning"

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# %% [markdown]
# we will use weights and biases (wandb) to keep track of our training process and evals.
#
# ```bash
# pip install wandb
# ```
#
# ```

# %%
import wandb

wandb.login()

wandb.init(project=WANDB_PROJECT)


run = wandb.init(project=WANDB_PROJECT, job_type="training")
# Out:
# wandb: Currently logged in as: kennygu (kennygu-georgetown-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/cs-data-01/ma2323/llm_tutorial/wandb/run-20250702_031653-vhqyoy7p</code>
# Syncing run <strong><a href='https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning/runs/vhqyoy7p' target="_blank">rosy-dust-3</a></strong> to <a href='https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning' target="_blank">https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning</a>
#  View run at <a href='https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning/runs/vhqyoy7p' target="_blank">https://wandb.ai/kennygu-georgetown-university/llama-imdb-finetuning/runs/vhqyoy7p</a>

# %%
# libs imports
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import bitsandbytes as bnb
import torch
import torch.nn as nn
import transformers
from datasets import Dataset
from peft import LoraConfig, PeftConfig
from trl import SFTTrainer, SFTConfig
from trl import setup_chat_format
from transformers import (AutoModelForCausalLM, 
                          AutoTokenizer, 
                          BitsAndBytesConfig, 
                          TrainingArguments, 
                          pipeline, 
                          logging)
from sklearn.metrics import (accuracy_score, 
                             classification_report, 
                             confusion_matrix)
from sklearn.model_selection import train_test_split
from datasets import Dataset
from accelerate import Accelerator

# %%
# important step when using accelerator to set the device index so that the model and the peft adapter are loaded on the same device


device_index = Accelerator().process_index

print(f"Using device index: {device_index}")

device_map = {"": device_index}
# Out:
# Using device index: 0

# %% [markdown]
# in this step we will load and process the dataset. to simplify things, we will use the same imdb dataset that we used with bert. recall this is a dataset of 50,000 movie reviews from the internet movie database. the reviews are labeled as positive or negative.
#
# after loading the dataset, we need to append our prompt to the begining of each review since we are finetuning a chat model.
#
# the training prompt structure is as follows:
#
# ```
# classify the sentiment of the following movie review as positive or negative. Respond with 'positive' or 'negative' and nothing else.
# review: {text}
# sentiment_label:
# ```
#
# the test prompt structure is as follows:
#
# ```
# classify the sentiment of the following movie review as positive or negative. Respond with 'positive' or 'negative' and nothing else.
# review: {text}
# sentiment_label:
# ```
#
# in this way we are instructing the model to generate the sentiment label (next token) for the review.

# %%
from bert_model import load_imdb_data

def generate_prompt(item):
    label = 'positive' if item['label'] == 1 else 'negative'
    prompt = f"""classify the sentiment of the following movie review as positive or negative. Respond with 'positive' or 'negative' and nothing else.

    review: {item['review']}
    sentiment_label: {label}
    """.strip()
    return {"text": prompt}

def generate_test_prompt(item):
    prompt = f"""classify the sentiment of the following movie review as positive or negative. Respond with 'positive' or 'negative' and nothing else.

    review: {item['review']}
    sentiment_label:
    """.strip()
    return {"text": prompt}

train_texts, train_labels, val_texts, val_labels, test_texts, test_labels = load_imdb_data(dataset_fraction=0.1)

train_dict = {
    'review': train_texts,
    'label': train_labels,
}

val_dict = {
    'review': val_texts,
    'label': val_labels,
}

test_dict = {
    'review': test_texts,
    'label': test_labels,
}

train_dataset = Dataset.from_dict(train_dict)
val_dataset = Dataset.from_dict(val_dict)
test_dataset = Dataset.from_dict(test_dict)

train_dataset = train_dataset.map(generate_prompt)
val_dataset = val_dataset.map(generate_prompt)
test_dataset = test_dataset.map(generate_test_prompt)

# print a sample of the dataset
print(train_dataset[0])
# Out:
# using device: cuda
# loading imdb dataset...
# using 10.0% of dataset
# train label distribution: Counter({1: 1258, 0: 1242})
# test label distribution: Counter({1: 1258, 0: 1242})
# train samples: 2500
# validation samples: 500
# test samples: 2000
# example review: An unusually straight-faced actioner played by a cast and filmed by a director who obviously took the material seriously. Imperfect, as is to be expected from a film clearly shot on a tight budget, bu...
# example label: 1 (positive)
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# {'review': 'An unusually straight-faced actioner played by a cast and filmed by a director who obviously took the material seriously. Imperfect, as is to be expected from a film clearly shot on a tight budget, but the drama is involving-- it\'s one of those films that when it gets repeated ad nauseum on Cinemax 2 or More Max or whatever they call it, you end up watching 40 minute blocks when you\'re supposed to be going to work. Along W/ "Deathstalker 2", "Chopping Mall", and "The Assault", a reminder that Wynorski is a much more talented director than many of his fellow low-budget brethern, who has a real ability to pace a genre film, when he actually\'s interested in the material (i.e., don\'t bother watching any of his Shannon Tweed flicks with a 3 or a 4 after the title!) Actors who\'ve had too little to do recently (Mancuso, Ford, even Gary Sandy for chrissakes) really put their all into some of their best roles in years -- as for Grieco, he has the right look, although his acting is a bit one-note -- it\'s clear his character is supposed to be self-destructing throughout the film, but Grieco doesn\'t quite convey it. I checked IMDB and I see the writer also wrote "Sorority House Massacre 2" & "Dinosaur Island" for the director -- both minor classics in their own rights, but obviously "silly" Roger Cormon-like Cinema -- this one\'s more like some of the better Jonathan Demme and Jonathan Kaplan B-pictures of the 70\'s -- giving you the exploitation element but offering involving drama at the same time -- a real step forward. Not "Citizen Kane," and the comic final moments are a bit disruptive, but a well-written, character-driven above-average straight-to-video actioner. Small achievements like this should not be overlooked when they come along, which is rare enough (as I was reminded as I tried to sit through an Albert Pyun monstrosity called "Heatseeker" the other night -- this low-budget stuff isn\'t as easy as it looks -- but that\'s another story!)', 'label': 1, 'text': 'classify the sentiment of the following movie review as positive or negative. Respond with \'positive\' or \'negative\' and nothing else.\n\n    review: An unusually straight-faced actioner played by a cast and filmed by a director who obviously took the material seriously. Imperfect, as is to be expected from a film clearly shot on a tight budget, but the drama is involving-- it\'s one of those films that when it gets repeated ad nauseum on Cinemax 2 or More Max or whatever they call it, you end up watching 40 minute blocks when you\'re supposed to be going to work. Along W/ "Deathstalker 2", "Chopping Mall", and "The Assault", a reminder that Wynorski is a much more talented director than many of his fellow low-budget brethern, who has a real ability to pace a genre film, when he actually\'s interested in the material (i.e., don\'t bother watching any of his Shannon Tweed flicks with a 3 or a 4 after the title!) Actors who\'ve had too little to do recently (Mancuso, Ford, even Gary Sandy for chrissakes) really put their all into some of their best roles in years -- as for Grieco, he has the right look, although his acting is a bit one-note -- it\'s clear his character is supposed to be self-destructing throughout the film, but Grieco doesn\'t quite convey it. I checked IMDB and I see the writer also wrote "Sorority House Massacre 2" & "Dinosaur Island" for the director -- both minor classics in their own rights, but obviously "silly" Roger Cormon-like Cinema -- this one\'s more like some of the better Jonathan Demme and Jonathan Kaplan B-pictures of the 70\'s -- giving you the exploitation element but offering involving drama at the same time -- a real step forward. Not "Citizen Kane," and the comic final moments are a bit disruptive, but a well-written, character-driven above-average straight-to-video actioner. Small achievements like this should not be overlooked when they come along, which is rare enough (as I was reminded as I tried to sit thro ...

# %% [markdown]
# now we will load the model and tokenizer. we will use the llama 3.2 3b model from the huggingface model hub. the model card can be found [here](https://huggingface.co/meta-llama/Llama-3.2-1B-Instruct).

# %%
base_model_name = "meta-llama/Llama-3.2-3B-Instruct"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16",
)

current_device = 2  # load model on gpu 3 - very important for quantized training
model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    device_map=device_map,  # use current device instead of auto
    torch_dtype="float16",
    quantization_config=bnb_config,
    cache_dir=CACHE_DIR,
)

model.config.use_cache = False
model.config.pretraining_tp = 1

tokenizer = AutoTokenizer.from_pretrained(base_model_name)

tokenizer.pad_token_id = tokenizer.eos_token_id
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# before finetuning, let's evaluate the model on the test set to measure its baseline performance.

# %%
def predict(test_dataset, model, tokenizer):
    y_pred = []
    categories = ["positive", "negative"]
    
    for i in tqdm(range(len(test_dataset))):
        prompt = test_dataset[i]["text"]
        pipe = pipeline(task="text-generation", 
                        model=model, 
                        tokenizer=tokenizer, 
                        max_new_tokens=2, 
                        temperature=0.1)
        
        result = pipe(prompt)
        answer = result[0]['generated_text'].split("sentiment_label:")[-1].strip()
        
        # determine the predicted category
        for category in categories:
            if category.lower() in answer.lower():
                y_pred.append(category)
                break
        else:
            y_pred.append("none")
    
    return y_pred



y_pred = predict(test_dataset, model, tokenizer)

print(y_pred)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]Device set to use cuda:2
#   0%|          | 1/2000 [00:00<04:11,  7.95it/s]Device set to use cuda:2
# Device set to use cuda:2
#   0%|          | 3/2000 [00:00<02:24, 13.81it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   0%|          | 6/2000 [00:00<01:54, 17.35it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   0%|          | 9/2000 [00:00<01:50, 18.00it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   1%|          | 12/2000 [00:00<01:43, 19.27it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   1%|          | 15/2000 [00:00<01:39, 20.04it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   1%|          | 18/2000 [00:00<01:36, 20.45it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   1%|          | 21/2000 [00:01<01:36, 20.57it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   1%|          | 24/2000 [00:01<01:35, 20.62it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   1%|▏         | 27/2000 [00:01<01:39, 19.75it/s]Device set to use cuda:2
# Device set to use cuda:2
#   1%|▏         | 29/2000 [00:01<01:42, 19.26it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   2%|▏         | 32/2000 [00:01<01:39, 19.80it/s]Device set to use cuda:2
# Device set to use cuda:2
#   2%|▏         | 34/2000 [00:01<01:44, 18.80it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   2%|▏         | 37/2000 [00:01<01:40, 19.48it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   2%|▏         | 40/2000 [00:02<01:38, 19.93it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   2%|▏         | 43/2000 [00:02<01:36, 20.25it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   2%|▏         | 46/2000 [00:02<01:35, 20.44it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   2%|▏         | 49/2000 [00:02<01:34, 20.60it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   3%|▎         | 52/2000 [00:02<01:33, 20.73it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   3%|▎         | 55/2000 [00:02<01:33, 20.84it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   3%|▎         | 58/2000 [00:02<01:34, 20.57it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   3%|▎         | 61/2000 [00:03<01:33, 20.69it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   3%|▎         | 64/2000 [00:03<01:35, 20.23it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   3%|▎         | 67/2000 [00:03<01:34, 20.44it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   4%|▎         | 70/2000 [00:03<01:33, 20.53it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   4%|▎         | 73/2000 [00:03<01:33, 20.64it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   4%|▍         | 76/2000 [00:03<01:36, 19.95it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   4%|▍         | 79/2000 [00:03<01:38, 19.57it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   4%|▍         | 82/2000 [00:04<01:36, 19.86it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   4%|▍         | 85/2000 [00:04<01:35, 20.09it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   4%|▍         | 88/2000 [00:04<01:36, 19.79it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   5%|▍         | 91/2000 [00:04<01:33, 20.39it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   5%|▍         | 94/2000 [00:04<01:38, 19.40it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   5%|▍         | 97/2000 [00:04<01:34, 20.10it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   5%|▌         | 100/2000 [00:05<01:32, 20.62it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   5%|▌         | 103/2000 [00:05<01:30, 20.99it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   5%|▌         | 106/2000 [00:05<01:29, 21.13it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   5%|▌         | 109/2000 [00:05<01:28, 21.28it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   6%|▌         | 112/2000 [00:05<01:27, 21.48it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   6%|▌         | 115/2000 [00:05<01:27, 21.61it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   6%|▌         | 118/2000 [00:05<01:29, 21.08it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   6%|▌         | 121/2000 [00:06<01:28, 21.32it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   6%|▌         | 124/2000 [00:06<01:27, 21.56it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   6%|▋         | 127/2000 [00:06<01:26, 21.73it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   6%|▋         | 130/2000 [00:06<01:25, 21.79it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   7%|▋         | 133/2000 [00:06<01:25, 21.90it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   7%|▋         | 136/2000 [00:06<01:30, 20.54it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   7%|▋         | 139/2000 [00:06<01:30, 20.61it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   7%|▋         | 142/2000 [00:07<01:31, 20.35it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   7%|▋         | 145/2000 [00:07<01:29, 20.78it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   7%|▋         | 148/2000 [00:07<01:27, 21.10it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   8%|▊         | 151/2000 [00:07<01:26, 21.41it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   8%|▊         | 154/2000 [00:07<01:25, 21.63it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   8%|▊         | 157/2000 [00:07<01:25, 21.58it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   8%|▊         | 160/2000 [00:07<01:24, 21.69it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   8%|▊         | 163/2000 [00:07<01:25, 21.61it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   8%|▊         | 166/2000 [00:08<01:30, 20.32it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   8%|▊         | 169/2000 [00:08<01:28, 20.80it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   9%|▊         | 172/2000 [00:08<01:28, 20.57it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   9%|▉         | 175/2000 [00:08<01:27, 20.87it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   9%|▉         | 178/2000 [00:08<01:25, 21.23it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   9%|▉         | 181/2000 [00:08<01:25, 21.24it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   9%|▉         | 184/2000 [00:08<01:24, 21.51it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#   9%|▉         | 187/2000 [00:09<01:27, 20.70it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  10%|▉         | 190/2000 [00:09<01:28, 20.42it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  10%|▉         | 193/2000 [00:09<01:26, 20.78it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  10%|▉         | 196/2000 [00:09<01:27, 20.72it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  10%|▉         | 199/2000 [00:09<01:25, 21.06it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  10%|█         | 202/2000 [00:09<01:24, 21.39it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  10%|█         | 205/2000 [00:09<01:23, 21.62it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  10%|█         | 208/2000 [00:10<01:22, 21.78it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  11%|█         | 211/2000 [00:10<01:22, 21.67it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  11%|█         | 214/2000 [00:10<01:23, 21.37it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  11%|█         | 217/2000 [00:10<01:22, 21.59it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  11%|█         | 220/2000 [00:10<01:23, 21.29it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  11%|█         | 223/2000 [00:10<01:22, 21.49it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  11%|█▏        | 226/2000 [00:10<01:22, 21.53it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  11%|█▏        | 229/2000 [00:11<01:22, 21.56it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  12%|█▏        | 232/2000 [00:11<01:25, 20.59it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  12%|█▏        | 235/2000 [00:11<01:23, 21.01it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  12%|█▏        | 238/2000 [00:11<01:23, 21.13it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  12%|█▏        | 241/2000 [00:11<01:21, 21.45it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  12%|█▏        | 244/2000 [00:11<01:21, 21.49it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  12%|█▏        | 247/2000 [00:11<01:20, 21.68it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  12%|█▎        | 250/2000 [00:12<01:20, 21.62it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  13%|█▎        | 253/2000 [00:12<01:20, 21.80it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  13%|█▎        | 256/2000 [00:12<01:19, 21.90it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  13%|█▎        | 259/2000 [00:12<01:21, 21.41it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  13%|█▎        | 262/2000 [00:12<01:25, 20.37it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  13%|█▎        | 265/2000 [00:12<01:25, 20.34it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  13%|█▎        | 268/2000 [00:12<01:26, 20.07it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  14%|█▎        | 271/2000 [00:13<01:23, 20.67it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  14%|█▎        | 274/2000 [00:13<01:23, 20.71it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  14%|█▍        | 277/2000 [00:13<01:23, 20.59it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  14%|█▍        | 280/2000 [00:13<01:24, 20.36it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  14%|█▍        | 283/2000 [00:13<01:22, 20.83it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  14%|█▍        | 286/2000 [00:13<01:20, 21.25it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  14%|█▍        | 289/2000 [00:13<01:19, 21.50it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  15%|█▍        | 292/2000 [00:14<01:21, 20.94it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  15%|█▍        | 295/2000 [00:14<01:20, 21.19it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  15%|█▍        | 298/2000 [00:14<01:20, 21.07it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  15%|█▌        | 301/2000 [00:14<01:20, 21.20it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  15%|█▌        | 304/2000 [00:14<01:21, 20.77it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  15%|█▌        | 307/2000 [00:14<01:20, 21.05it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  16%|█▌        | 310/2000 [00:14<01:20, 21.12it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  16%|█▌        | 313/2000 [00:15<01:18, 21.41it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  16%|█▌        | 316/2000 [00:15<01:18, 21.48it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  16%|█▌        | 319/2000 [00:15<01:17, 21.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  16%|█▌        | 322/2000 [00:15<01:17, 21.61it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  16%|█▋        | 325/2000 [00:15<01:17, 21.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  16%|█▋        | 328/2000 [00:15<01:21, 20.40it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  17%|█▋        | 331/2000 [00:15<01:20, 20.78it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  17%|█▋        | 334/2000 [00:16<01:22, 20.19it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  17%|█▋        | 337/2000 [00:16<01:20, 20.69it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  17%|█▋        | 340/2000 [00:16<01:19, 20.98it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  17%|█▋        | 343/2000 [00:16<01:22, 19.99it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  17%|█▋        | 346/2000 [00:16<01:22, 19.99it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  17%|█▋        | 349/2000 [00:16<01:20, 20.48it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  18%|█▊        | 352/2000 [00:16<01:20, 20.54it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  18%|█▊        | 355/2000 [00:17<01:24, 19.58it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  18%|█▊        | 358/2000 [00:17<01:21, 20.17it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  18%|█▊        | 361/2000 [00:17<01:19, 20.73it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  18%|█▊        | 364/2000 [00:17<01:17, 21.11it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  18%|█▊        | 367/2000 [00:17<01:16, 21.37it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  18%|█▊        | 370/2000 [00:17<01:21, 19.95it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  19%|█▊        | 373/2000 [00:18<01:19, 20.40it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  19%|█▉        | 376/2000 [00:18<01:18, 20.68it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  19%|█▉        | 379/2000 [00:18<01:17, 21.05it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  19%|█▉        | 382/2000 [00:18<01:18, 20.48it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  19%|█▉        | 385/2000 [00:18<01:17, 20.94it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  19%|█▉        | 388/2000 [00:18<01:16, 21.21it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  20%|█▉        | 391/2000 [00:18<01:17, 20.81it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  20%|█▉        | 394/2000 [00:18<01:15, 21.20it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  20%|█▉        | 397/2000 [00:19<01:14, 21.43it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  20%|██        | 400/2000 [00:19<01:15, 21.14it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  20%|██        | 403/2000 [00:19<01:14, 21.32it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  20%|██        | 406/2000 [00:19<01:15, 21.00it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  20%|██        | 409/2000 [00:19<01:16, 20.86it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  21%|██        | 412/2000 [00:19<01:15, 21.01it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  21%|██        | 415/2000 [00:19<01:14, 21.19it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  21%|██        | 418/2000 [00:20<01:16, 20.75it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  21%|██        | 421/2000 [00:20<01:15, 20.99it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  21%|██        | 424/2000 [00:20<01:14, 21.27it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  21%|██▏       | 427/2000 [00:20<01:13, 21.48it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  22%|██▏       | 430/2000 [00:20<01:12, 21.66it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  22%|██▏       | 433/2000 [00:20<01:14, 21.13it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  22%|██▏       | 436/2000 [00:20<01:14, 21.00it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  22%|██▏       | 439/2000 [00:21<01:15, 20.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  22%|██▏       | 442/2000 [00:21<01:14, 20.95it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  22%|██▏       | 445/2000 [00:21<01:13, 21.15it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  22%|██▏       | 448/2000 [00:21<01:12, 21.43it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  23%|██▎       | 451/2000 [00:21<01:14, 20.92it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  23%|██▎       | 454/2000 [00:21<01:12, 21.29it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  23%|██▎       | 457/2000 [00:21<01:15, 20.49it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  23%|██▎       | 460/2000 [00:22<01:19, 19.37it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  23%|██▎       | 463/2000 [00:22<01:16, 20.11it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  23%|██▎       | 466/2000 [00:22<01:14, 20.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  23%|██▎       | 469/2000 [00:22<01:12, 21.07it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  24%|██▎       | 472/2000 [00:22<01:11, 21.33it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  24%|██▍       | 475/2000 [00:22<01:14, 20.45it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  24%|██▍       | 478/2000 [00:23<01:12, 20.88it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  24%|██▍       | 481/2000 [00:23<01:11, 21.24it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  24%|██▍       | 484/2000 [00:23<01:10, 21.44it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  24%|██▍       | 487/2000 [00:23<01:13, 20.70it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  24%|██▍       | 490/2000 [00:23<01:11, 21.00it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  25%|██▍       | 493/2000 [00:23<01:10, 21.27it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  25%|██▍       | 496/2000 [00:23<01:10, 21.37it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  25%|██▍       | 499/2000 [00:23<01:09, 21.51it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  25%|██▌       | 502/2000 [00:24<01:09, 21.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  25%|██▌       | 505/2000 [00:24<01:11, 20.91it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  25%|██▌       | 508/2000 [00:24<01:15, 19.85it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  26%|██▌       | 511/2000 [00:24<01:12, 20.44it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  26%|██▌       | 514/2000 [00:24<01:13, 20.11it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  26%|██▌       | 517/2000 [00:24<01:11, 20.66it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  26%|██▌       | 520/2000 [00:25<01:10, 21.06it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  26%|██▌       | 523/2000 [00:25<01:10, 21.05it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  26%|██▋       | 526/2000 [00:25<01:09, 21.26it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  26%|██▋       | 529/2000 [00:25<01:10, 20.85it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  27%|██▋       | 532/2000 [00:25<01:10, 20.74it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  27%|██▋       | 535/2000 [00:25<01:09, 21.12it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  27%|██▋       | 538/2000 [00:25<01:09, 20.90it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  27%|██▋       | 541/2000 [00:26<01:08, 21.26it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  27%|██▋       | 544/2000 [00:26<01:08, 21.34it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  27%|██▋       | 547/2000 [00:26<01:07, 21.59it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  28%|██▊       | 550/2000 [00:26<01:06, 21.76it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  28%|██▊       | 553/2000 [00:26<01:06, 21.91it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  28%|██▊       | 556/2000 [00:26<01:07, 21.33it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  28%|██▊       | 559/2000 [00:26<01:07, 21.39it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  28%|██▊       | 562/2000 [00:26<01:06, 21.60it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  28%|██▊       | 565/2000 [00:27<01:06, 21.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  28%|██▊       | 568/2000 [00:27<01:05, 21.71it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  29%|██▊       | 571/2000 [00:27<01:08, 20.99it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  29%|██▊       | 574/2000 [00:27<01:07, 21.24it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  29%|██▉       | 577/2000 [00:27<01:06, 21.35it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  29%|██▉       | 580/2000 [00:27<01:05, 21.53it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  29%|██▉       | 583/2000 [00:27<01:05, 21.53it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  29%|██▉       | 586/2000 [00:28<01:05, 21.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  29%|██▉       | 589/2000 [00:28<01:08, 20.51it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  30%|██▉       | 592/2000 [00:28<01:07, 20.82it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  30%|██▉       | 595/2000 [00:28<01:06, 21.19it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  30%|██▉       | 598/2000 [00:28<01:05, 21.40it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  30%|███       | 601/2000 [00:28<01:04, 21.59it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  30%|███       | 604/2000 [00:28<01:05, 21.26it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  30%|███       | 607/2000 [00:29<01:05, 21.43it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  30%|███       | 610/2000 [00:29<01:04, 21.61it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  31%|███       | 613/2000 [00:29<01:04, 21.63it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  31%|███       | 616/2000 [00:29<01:03, 21.74it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  31%|███       | 619/2000 [00:29<01:03, 21.86it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  31%|███       | 622/2000 [00:29<01:03, 21.80it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  31%|███▏      | 625/2000 [00:29<01:02, 21.91it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  31%|███▏      | 628/2000 [00:30<01:02, 21.87it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  32%|███▏      | 631/2000 [00:30<01:03, 21.45it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  32%|███▏      | 634/2000 [00:30<01:03, 21.46it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  32%|███▏      | 637/2000 [00:30<01:02, 21.69it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  32%|███▏      | 640/2000 [00:30<01:02, 21.70it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  32%|███▏      | 643/2000 [00:30<01:04, 20.96it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  32%|███▏      | 646/2000 [00:30<01:07, 20.06it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  32%|███▏      | 649/2000 [00:31<01:08, 19.84it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  33%|███▎      | 652/2000 [00:31<01:05, 20.44it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  33%|███▎      | 655/2000 [00:31<01:04, 20.74it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  33%|███▎      | 658/2000 [00:31<01:04, 20.97it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  33%|███▎      | 661/2000 [00:31<01:03, 21.18it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  33%|███▎      | 664/2000 [00:31<01:04, 20.69it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  33%|███▎      | 667/2000 [00:31<01:03, 20.97it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  34%|███▎      | 670/2000 [00:32<01:02, 21.18it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  34%|███▎      | 673/2000 [00:32<01:01, 21.48it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  34%|███▍      | 676/2000 [00:32<01:02, 21.07it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  34%|███▍      | 679/2000 [00:32<01:02, 21.30it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  34%|███▍      | 682/2000 [00:32<01:04, 20.40it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  34%|███▍      | 685/2000 [00:32<01:02, 20.89it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  34%|███▍      | 688/2000 [00:32<01:01, 21.21it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  35%|███▍      | 691/2000 [00:33<01:01, 21.46it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  35%|███▍      | 694/2000 [00:33<01:00, 21.43it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  35%|███▍      | 697/2000 [00:33<01:02, 20.96it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  35%|███▌      | 700/2000 [00:33<01:01, 21.27it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  35%|███▌      | 703/2000 [00:33<01:00, 21.43it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  35%|███▌      | 706/2000 [00:33<01:00, 21.55it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  35%|███▌      | 709/2000 [00:33<00:59, 21.71it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  36%|███▌      | 712/2000 [00:34<01:03, 20.31it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  36%|███▌      | 715/2000 [00:34<01:01, 20.80it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  36%|███▌      | 718/2000 [00:34<01:00, 21.18it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  36%|███▌      | 721/2000 [00:34<01:01, 20.88it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  36%|███▌      | 724/2000 [00:34<01:00, 21.23it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  36%|███▋      | 727/2000 [00:34<01:01, 20.73it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  36%|███▋      | 730/2000 [00:34<01:00, 21.08it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  37%|███▋      | 733/2000 [00:35<01:00, 20.91it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  37%|███▋      | 736/2000 [00:35<00:59, 21.19it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  37%|███▋      | 739/2000 [00:35<01:00, 20.77it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  37%|███▋      | 742/2000 [00:35<00:59, 21.05it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  37%|███▋      | 745/2000 [00:35<01:00, 20.81it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  37%|███▋      | 748/2000 [00:35<01:02, 19.90it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  38%|███▊      | 751/2000 [00:35<01:00, 20.50it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  38%|███▊      | 754/2000 [00:36<00:59, 20.95it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  38%|███▊      | 757/2000 [00:36<00:58, 21.22it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  38%|███▊      | 760/2000 [00:36<00:57, 21.41it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  38%|███▊      | 763/2000 [00:36<01:01, 20.17it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  38%|███▊      | 766/2000 [00:36<00:59, 20.68it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  38%|███▊      | 769/2000 [00:36<00:58, 21.04it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  39%|███▊      | 772/2000 [00:36<00:58, 20.94it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  39%|███▉      | 775/2000 [00:37<00:58, 20.81it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  39%|███▉      | 778/2000 [00:37<00:58, 20.75it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  39%|███▉      | 781/2000 [00:37<00:57, 21.14it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  39%|███▉      | 784/2000 [00:37<00:57, 21.03it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  39%|███▉      | 787/2000 [00:37<00:57, 21.23it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  40%|███▉      | 790/2000 [00:37<00:59, 20.29it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  40%|███▉      | 793/2000 [00:37<00:58, 20.71it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  40%|███▉      | 796/2000 [00:38<00:58, 20.73it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  40%|███▉      | 799/2000 [00:38<00:58, 20.45it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  40%|████      | 802/2000 [00:38<00:57, 20.80it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  40%|████      | 805/2000 [00:38<00:57, 20.76it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  40%|████      | 808/2000 [00:38<00:56, 21.04it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  41%|████      | 811/2000 [00:38<00:55, 21.42it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  41%|████      | 814/2000 [00:38<00:55, 21.56it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  41%|████      | 817/2000 [00:39<00:58, 20.29it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  41%|████      | 820/2000 [00:39<00:58, 20.14it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  41%|████      | 823/2000 [00:39<00:56, 20.69it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  41%|████▏     | 826/2000 [00:39<00:55, 20.99it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  41%|████▏     | 829/2000 [00:39<00:54, 21.30it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  42%|████▏     | 832/2000 [00:39<00:55, 20.97it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  42%|████▏     | 835/2000 [00:39<00:58, 20.01it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  42%|████▏     | 838/2000 [00:40<00:58, 19.95it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  42%|████▏     | 841/2000 [00:40<00:56, 20.53it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  42%|████▏     | 844/2000 [00:40<00:55, 20.96it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  42%|████▏     | 847/2000 [00:40<00:54, 21.32it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  42%|████▎     | 850/2000 [00:40<00:55, 20.77it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  43%|████▎     | 853/2000 [00:40<00:55, 20.56it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  43%|████▎     | 856/2000 [00:40<00:54, 20.94it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  43%|████▎     | 859/2000 [00:41<00:53, 21.28it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  43%|████▎     | 862/2000 [00:41<00:53, 21.31it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  43%|████▎     | 865/2000 [00:41<00:54, 20.66it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  43%|████▎     | 868/2000 [00:41<00:53, 21.11it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  44%|████▎     | 871/2000 [00:41<00:52, 21.39it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  44%|████▎     | 874/2000 [00:41<00:52, 21.58it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  44%|████▍     | 877/2000 [00:41<00:51, 21.70it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  44%|████▍     | 880/2000 [00:42<00:56, 19.89it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  44%|████▍     | 883/2000 [00:42<00:55, 19.96it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  44%|████▍     | 886/2000 [00:42<00:54, 20.37it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  44%|████▍     | 889/2000 [00:42<00:54, 20.47it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  45%|████▍     | 892/2000 [00:42<00:54, 20.17it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  45%|████▍     | 895/2000 [00:42<00:56, 19.41it/s]Device set to use cuda:2
# Device set to use cuda:2
#  45%|████▍     | 897/2000 [00:42<00:57, 19.13it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  45%|████▌     | 900/2000 [00:43<00:55, 19.82it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  45%|████▌     | 903/2000 [00:43<00:54, 20.28it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  45%|████▌     | 906/2000 [00:43<00:54, 19.97it/s]Device set to use cuda:2
# Device set to use cuda:2
#  45%|████▌     | 908/2000 [00:43<00:56, 19.46it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  46%|████▌     | 911/2000 [00:43<00:53, 20.22it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  46%|████▌     | 914/2000 [00:43<00:52, 20.71it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  46%|████▌     | 917/2000 [00:43<00:51, 21.09it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  46%|████▌     | 920/2000 [00:44<00:50, 21.33it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  46%|████▌     | 923/2000 [00:44<00:51, 21.09it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  46%|████▋     | 926/2000 [00:44<00:51, 20.84it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  46%|████▋     | 929/2000 [00:44<00:50, 21.09it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  47%|████▋     | 932/2000 [00:44<00:50, 21.33it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  47%|████▋     | 935/2000 [00:44<00:49, 21.51it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  47%|████▋     | 938/2000 [00:44<00:50, 20.82it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  47%|████▋     | 941/2000 [00:45<00:51, 20.46it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  47%|████▋     | 944/2000 [00:45<00:50, 20.80it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  47%|████▋     | 947/2000 [00:45<00:50, 21.02it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  48%|████▊     | 950/2000 [00:45<00:49, 21.32it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  48%|████▊     | 953/2000 [00:45<00:48, 21.55it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  48%|████▊     | 956/2000 [00:45<00:49, 21.24it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  48%|████▊     | 959/2000 [00:45<00:49, 21.01it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  48%|████▊     | 962/2000 [00:46<00:48, 21.30it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  48%|████▊     | 965/2000 [00:46<00:49, 20.82it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  48%|████▊     | 968/2000 [00:46<00:50, 20.35it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  49%|████▊     | 971/2000 [00:46<00:49, 20.81it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  49%|████▊     | 974/2000 [00:46<00:50, 20.45it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  49%|████▉     | 977/2000 [00:46<00:50, 20.37it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  49%|████▉     | 980/2000 [00:46<00:50, 20.35it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  49%|████▉     | 983/2000 [00:47<00:48, 20.83it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  49%|████▉     | 986/2000 [00:47<00:47, 21.17it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  49%|████▉     | 989/2000 [00:47<00:48, 20.78it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  50%|████▉     | 992/2000 [00:47<00:47, 21.06it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  50%|████▉     | 995/2000 [00:47<00:48, 20.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  50%|████▉     | 998/2000 [00:47<00:47, 21.03it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  50%|█████     | 1001/2000 [00:47<00:47, 20.92it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  50%|█████     | 1004/2000 [00:48<00:48, 20.64it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  50%|█████     | 1007/2000 [00:48<00:47, 21.06it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  50%|█████     | 1010/2000 [00:48<00:49, 19.92it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  51%|█████     | 1013/2000 [00:48<00:48, 20.46it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  51%|█████     | 1016/2000 [00:48<00:47, 20.70it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  51%|█████     | 1019/2000 [00:48<00:47, 20.57it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  51%|█████     | 1022/2000 [00:48<00:46, 21.00it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  51%|█████▏    | 1025/2000 [00:49<00:47, 20.67it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  51%|█████▏    | 1028/2000 [00:49<00:46, 20.93it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  52%|█████▏    | 1031/2000 [00:49<00:47, 20.39it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  52%|█████▏    | 1034/2000 [00:49<00:47, 20.32it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  52%|█████▏    | 1037/2000 [00:49<00:46, 20.81it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  52%|█████▏    | 1040/2000 [00:49<00:45, 21.16it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  52%|█████▏    | 1043/2000 [00:49<00:44, 21.28it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  52%|█████▏    | 1046/2000 [00:50<00:48, 19.58it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  52%|█████▏    | 1049/2000 [00:50<00:46, 20.25it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  53%|█████▎    | 1052/2000 [00:50<00:45, 20.76it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  53%|█████▎    | 1055/2000 [00:50<00:46, 20.50it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  53%|█████▎    | 1058/2000 [00:50<00:46, 20.25it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  53%|█████▎    | 1061/2000 [00:50<00:45, 20.63it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  53%|█████▎    | 1064/2000 [00:51<00:44, 20.88it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  53%|█████▎    | 1067/2000 [00:51<00:43, 21.23it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  54%|█████▎    | 1070/2000 [00:51<00:44, 20.83it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  54%|█████▎    | 1073/2000 [00:51<00:43, 21.15it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  54%|█████▍    | 1076/2000 [00:51<00:43, 21.43it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  54%|█████▍    | 1079/2000 [00:51<00:42, 21.58it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  54%|█████▍    | 1082/2000 [00:51<00:44, 20.85it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  54%|█████▍    | 1085/2000 [00:52<00:44, 20.51it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  54%|█████▍    | 1088/2000 [00:52<00:43, 20.89it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  55%|█████▍    | 1091/2000 [00:52<00:42, 21.19it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  55%|█████▍    | 1094/2000 [00:52<00:42, 21.36it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  55%|█████▍    | 1097/2000 [00:52<00:43, 20.81it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  55%|█████▌    | 1100/2000 [00:52<00:42, 21.13it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  55%|█████▌    | 1103/2000 [00:52<00:43, 20.68it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  55%|█████▌    | 1106/2000 [00:53<00:43, 20.68it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  55%|█████▌    | 1109/2000 [00:53<00:43, 20.31it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  56%|█████▌    | 1112/2000 [00:53<00:43, 20.54it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  56%|█████▌    | 1115/2000 [00:53<00:43, 20.51it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  56%|█████▌    | 1118/2000 [00:53<00:42, 20.73it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  56%|█████▌    | 1121/2000 [00:53<00:42, 20.48it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  56%|█████▌    | 1124/2000 [00:53<00:41, 20.91it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  56%|█████▋    | 1127/2000 [00:54<00:42, 20.45it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  56%|█████▋    | 1130/2000 [00:54<00:41, 20.94it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  57%|█████▋    | 1133/2000 [00:54<00:42, 20.60it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  57%|█████▋    | 1136/2000 [00:54<00:42, 20.40it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  57%|█████▋    | 1139/2000 [00:54<00:41, 20.89it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  57%|█████▋    | 1142/2000 [00:54<00:40, 21.21it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  57%|█████▋    | 1145/2000 [00:54<00:40, 20.99it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
# ...
#  86%|████████▌ | 1717/2000 [01:22<00:16, 17.46it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  86%|████████▌ | 1720/2000 [01:22<00:15, 18.61it/s]Device set to use cuda:2
# Device set to use cuda:2
#  86%|████████▌ | 1722/2000 [01:22<00:14, 18.86it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  86%|████████▋ | 1725/2000 [01:22<00:13, 19.75it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  86%|████████▋ | 1728/2000 [01:22<00:13, 20.18it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  87%|████████▋ | 1731/2000 [01:23<00:13, 20.68it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  87%|████████▋ | 1734/2000 [01:23<00:13, 20.35it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  87%|████████▋ | 1737/2000 [01:23<00:12, 20.66it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  87%|████████▋ | 1740/2000 [01:23<00:12, 21.04it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  87%|████████▋ | 1743/2000 [01:23<00:12, 20.33it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  87%|████████▋ | 1746/2000 [01:23<00:12, 20.53it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  87%|████████▋ | 1749/2000 [01:24<00:11, 20.95it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  88%|████████▊ | 1752/2000 [01:24<00:11, 21.12it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  88%|████████▊ | 1755/2000 [01:24<00:11, 21.40it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  88%|████████▊ | 1758/2000 [01:24<00:11, 21.49it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  88%|████████▊ | 1761/2000 [01:24<00:11, 21.21it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  88%|████████▊ | 1764/2000 [01:24<00:11, 20.35it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  88%|████████▊ | 1767/2000 [01:24<00:11, 20.64it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  88%|████████▊ | 1770/2000 [01:25<00:10, 20.98it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  89%|████████▊ | 1773/2000 [01:25<00:10, 21.21it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  89%|████████▉ | 1776/2000 [01:25<00:10, 21.36it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  89%|████████▉ | 1779/2000 [01:25<00:10, 21.53it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  89%|████████▉ | 1782/2000 [01:25<00:10, 21.53it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  89%|████████▉ | 1785/2000 [01:25<00:10, 20.92it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  89%|████████▉ | 1788/2000 [01:25<00:09, 21.20it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  90%|████████▉ | 1791/2000 [01:25<00:09, 21.34it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  90%|████████▉ | 1794/2000 [01:26<00:09, 20.77it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  90%|████████▉ | 1797/2000 [01:26<00:09, 20.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  90%|█████████ | 1800/2000 [01:26<00:09, 20.54it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  90%|█████████ | 1803/2000 [01:26<00:09, 20.78it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  90%|█████████ | 1806/2000 [01:26<00:09, 20.45it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  90%|█████████ | 1809/2000 [01:26<00:09, 20.66it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  91%|█████████ | 1812/2000 [01:27<00:09, 20.49it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  91%|█████████ | 1815/2000 [01:27<00:08, 20.83it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  91%|█████████ | 1818/2000 [01:27<00:08, 20.58it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  91%|█████████ | 1821/2000 [01:27<00:08, 20.92it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  91%|█████████ | 1824/2000 [01:27<00:08, 21.08it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  91%|█████████▏| 1827/2000 [01:27<00:08, 21.23it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  92%|█████████▏| 1830/2000 [01:27<00:08, 21.24it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  92%|█████████▏| 1833/2000 [01:27<00:07, 21.42it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  92%|█████████▏| 1836/2000 [01:28<00:07, 21.58it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  92%|█████████▏| 1839/2000 [01:28<00:07, 21.29it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  92%|█████████▏| 1842/2000 [01:28<00:07, 20.12it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  92%|█████████▏| 1845/2000 [01:28<00:07, 20.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  92%|█████████▏| 1848/2000 [01:28<00:07, 21.03it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  93%|█████████▎| 1851/2000 [01:28<00:07, 20.86it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  93%|█████████▎| 1854/2000 [01:29<00:07, 19.49it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  93%|█████████▎| 1857/2000 [01:29<00:07, 20.17it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  93%|█████████▎| 1860/2000 [01:29<00:06, 20.68it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  93%|█████████▎| 1863/2000 [01:29<00:06, 20.55it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  93%|█████████▎| 1866/2000 [01:29<00:06, 20.33it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  93%|█████████▎| 1869/2000 [01:29<00:06, 20.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  94%|█████████▎| 1872/2000 [01:29<00:06, 20.28it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  94%|█████████▍| 1875/2000 [01:30<00:06, 20.19it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  94%|█████████▍| 1878/2000 [01:30<00:05, 20.70it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  94%|█████████▍| 1881/2000 [01:30<00:05, 20.04it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  94%|█████████▍| 1884/2000 [01:30<00:05, 20.57it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  94%|█████████▍| 1887/2000 [01:30<00:05, 20.35it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  94%|█████████▍| 1890/2000 [01:30<00:05, 20.40it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  95%|█████████▍| 1893/2000 [01:30<00:05, 20.69it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  95%|█████████▍| 1896/2000 [01:31<00:05, 19.13it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  95%|█████████▍| 1899/2000 [01:31<00:05, 19.90it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  95%|█████████▌| 1902/2000 [01:31<00:05, 19.10it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  95%|█████████▌| 1905/2000 [01:31<00:04, 19.83it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  95%|█████████▌| 1908/2000 [01:31<00:04, 20.47it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  96%|█████████▌| 1911/2000 [01:31<00:04, 19.57it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  96%|█████████▌| 1914/2000 [01:32<00:04, 20.07it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  96%|█████████▌| 1917/2000 [01:32<00:04, 19.40it/s]Device set to use cuda:2
# Device set to use cuda:2
#  96%|█████████▌| 1919/2000 [01:32<00:04, 18.83it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  96%|█████████▌| 1922/2000 [01:32<00:04, 19.21it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  96%|█████████▋| 1925/2000 [01:32<00:03, 20.02it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  96%|█████████▋| 1928/2000 [01:32<00:03, 19.65it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  97%|█████████▋| 1931/2000 [01:32<00:03, 20.27it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  97%|█████████▋| 1934/2000 [01:33<00:03, 20.72it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  97%|█████████▋| 1937/2000 [01:33<00:03, 19.35it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  97%|█████████▋| 1940/2000 [01:33<00:02, 20.10it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  97%|█████████▋| 1943/2000 [01:33<00:02, 20.53it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  97%|█████████▋| 1946/2000 [01:33<00:02, 20.38it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  97%|█████████▋| 1949/2000 [01:33<00:02, 20.88it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  98%|█████████▊| 1952/2000 [01:33<00:02, 21.23it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  98%|█████████▊| 1955/2000 [01:34<00:02, 21.33it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  98%|█████████▊| 1958/2000 [01:34<00:01, 21.50it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  98%|█████████▊| 1961/2000 [01:34<00:01, 21.54it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  98%|█████████▊| 1964/2000 [01:34<00:01, 21.69it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  98%|█████████▊| 1967/2000 [01:34<00:01, 20.90it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  98%|█████████▊| 1970/2000 [01:34<00:01, 20.37it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  99%|█████████▊| 1973/2000 [01:34<00:01, 20.85it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  99%|█████████▉| 1976/2000 [01:35<00:01, 21.15it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  99%|█████████▉| 1979/2000 [01:35<00:00, 21.40it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  99%|█████████▉| 1982/2000 [01:35<00:00, 21.58it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  99%|█████████▉| 1985/2000 [01:35<00:00, 21.22it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
#  99%|█████████▉| 1988/2000 [01:35<00:00, 20.55it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
# 100%|█████████▉| 1991/2000 [01:35<00:00, 20.77it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
# 100%|█████████▉| 1994/2000 [01:35<00:00, 20.73it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
# 100%|█████████▉| 1997/2000 [01:36<00:00, 20.37it/s]Device set to use cuda:2
# Device set to use cuda:2
# Device set to use cuda:2
# 100%|██████████| 2000/2000 [01:36<00:00, 20.79it/s]
# ['positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'negative', 'positive', 'positive', 'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'positive', 'positive', 'negative', 'negative', 'positive', 'positive', 'positive', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 'positive', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'positive', 'positive', 'negative', 'positive', 'negative', 'negative', 'positive', 'positive', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 'negative', 'negative', 'positive', 'positive', 'positive', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'positive', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'positive', 'negative', 'positive', 'positive', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'positive', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'positive', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'positive', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'negative', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'none', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'positive', 'negative', 'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'positive', 'negative', 'positi ...

# %% [markdown]
# next we evaluate the baselinemodel's performance on the test set.

# %%
def evaluate(y_true, y_pred):
    labels = ["positive", "negative"]
    mapping = {label: idx for idx, label in enumerate(labels)}
    
    def map_func(x):
        return mapping.get(x, -1)  # Map to -1 if not found, but should not occur with correct data
    
    y_true_mapped = np.vectorize(map_func)(y_true)
    y_pred_mapped = np.vectorize(map_func)(y_pred)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_true=y_true_mapped, y_pred=y_pred_mapped)
    print(f'Accuracy: {accuracy:.3f}')
    
    # Generate accuracy report
    unique_labels = set(y_true_mapped)  # Get unique labels
    
    for label in unique_labels:
        label_indices = [i for i in range(len(y_true_mapped)) if y_true_mapped[i] == label]
        label_y_true = [y_true_mapped[i] for i in label_indices]
        label_y_pred = [y_pred_mapped[i] for i in label_indices]
        label_accuracy = accuracy_score(label_y_true, label_y_pred)
        print(f'Accuracy for label {labels[label]}: {label_accuracy:.3f}')
        
    # Generate classification report
    class_report = classification_report(y_true=y_true_mapped, y_pred=y_pred_mapped, target_names=labels, labels=list(range(len(labels))))
    print('\nClassification Report:')
    print(class_report)
    
    # Generate confusion matrix
    conf_matrix = confusion_matrix(y_true=y_true_mapped, y_pred=y_pred_mapped, labels=list(range(len(labels))))
    print('\nConfusion Matrix:')
    print(conf_matrix)

y_true = test_dataset["label"]
y_true = ["positive" if label == 1 else "negative" for label in y_true]
evaluate(y_true, y_pred)
# Out:
# Accuracy: 0.930
# Accuracy for label positive: 0.957
# Accuracy for label negative: 0.903
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     positive       0.91      0.96      0.93      1006
#     negative       0.96      0.90      0.93       994
#
#    micro avg       0.93      0.93      0.93      2000
#    macro avg       0.93      0.93      0.93      2000
# weighted avg       0.93      0.93      0.93      2000
#
#
# Confusion Matrix:
# [[963  42]
#  [ 95 898]]

# %% [markdown]
# as you can see, the model is already at a very good accuracy. that's because the dataset is super easy. let's see if we can push it a bit more by finetuning.

# %% [markdown]
# we will start building the model according to the following steps:
#
# 1. we extract all the linear modules from the models using the bitsandbytes library.
# 2. then we configure LoRA to target these linear modules.
# 3. we create a trainer object that will handle (and abstract) the training loop. using the trl library.
# 4. we train and evaluate the model.

# %%
import bitsandbytes as bnb

def find_all_linear_names(model):
    cls = bnb.nn.Linear4bit
    lora_module_names = set()
    for name, module in model.named_modules():
        if isinstance(module, cls):
            names = name.split('.')
            lora_module_names.add(names[0] if len(names) == 1 else names[-1])
    if 'lm_head' in lora_module_names:  # needed for 16 bit
        lora_module_names.remove('lm_head')
    return list(lora_module_names)
modules = find_all_linear_names(model)
modules
# Out:
# ['o_proj', 'q_proj', 'v_proj', 'up_proj', 'gate_proj', 'k_proj', 'down_proj']

# %%
# main training loop

output_dir= OUTPUT_DIR

peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=modules,
)

sft_config = SFTConfig(
    output_dir=output_dir,                    # directory to save and repository id
    num_train_epochs=1,                       # number of training epochs
    per_device_train_batch_size=1,            # batch size per device during training
    gradient_accumulation_steps=8,            # number of steps before performing a backward/update pass
    gradient_checkpointing=True,              # use gradient checkpointing to save memory
    optim="paged_adamw_32bit",
    logging_steps=1,                         
    learning_rate=2e-4,                       # learning rate, based on QLoRA paper
    weight_decay=0.001,
    fp16=True,
    bf16=False,
    max_grad_norm=0.3,                        # max gradient norm based on QLoRA paper
    max_steps=-1,
    warmup_ratio=0.03,                        # warmup ratio based on QLoRA paper
    group_by_length=False,
    lr_scheduler_type="cosine",               # use cosine learning rate scheduler
    report_to="wandb",                  # report metrics to w&b
    do_eval=True,
    eval_strategy="steps",              # save checkpoint every epoch
    eval_steps = 0.2,
    dataset_text_field="text",
    max_seq_length=512,
    packing=False,
    dataset_kwargs={"add_special_tokens": False, "append_concat_token": False},
    label_names=["label"],
)


trainer = SFTTrainer(
    model=model,
    args=sft_config,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    peft_config=peft_config,
    processing_class=tokenizer
)
# Out:
# average_tokens_across_devices is set to True but it is invalid when world size is1. Turn it to False automatically.
# Adding EOS to train dataset:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/500 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/500 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/500 [00:00<?, ? examples/s]

# %%
# now it's time to start the training loop
trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
#     <div>
#
#       <progress value='313' max='313' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [313/313 10:19, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>63</td>
#       <td>2.755700</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>126</td>
#       <td>2.615500</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>189</td>
#       <td>2.729500</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>252</td>
#       <td>2.350100</td>
#       <td>No log</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=313, training_loss=2.6217118345510464, metrics={'train_runtime': 621.6096, 'train_samples_per_second': 4.022, 'train_steps_per_second': 0.504, 'total_flos': 1.3084378739656704e+16, 'train_loss': 2.6217118345510464})
